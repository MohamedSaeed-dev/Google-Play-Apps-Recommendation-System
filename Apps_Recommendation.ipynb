# %% [markdown]
# # Recommendation System for Google Play Store
#
# * Using Apriori algorithm for implementing the recommendations (Association Rule)
#
# - The result would be the recommended two apps that users most loved
# - only for apps that users rated them above the average value (Good rating)

# %% [markdown]
# - ### About Me
#     - #### By Mohamed Saeed Ali bin Omar | Computer Science
#     - #### GitHub: https://github.com/MohamedSaeed-dev

# %% [markdown]
# ## Import the required libraries
# - ### Pandas:
#     is a Python library used for working with data sets. It provides powerful functions for analyzing, cleaning, exploring, and manipulating data.
#
# - ### Apyori:
#     is a Python library that provides a simple implementation of the Apriori algorithm, and widely used for association rule mining.

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Read the Google Play Store datasets

# %%
# Google Play Store Dataset

apps_data = pd.read_csv("./googleplaystore.csv")
users_data = pd.read_csv("./users.csv")
display(apps_data)
print(apps_data.shape)

display(users_data)
print(users_data.shape)
# Out:
#                                                 App_Name             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver  App_ID
# 0                   1.0.0        4.0.3 and up       1
# 1                   2.0.0        4.0.3 and up       2
# 2                   1.2.4        4.0.3 and up       3
# 3      Varies with device          4.2 and up       4
# 4                     1.1          4.4 and up       5
# ...                   ...                 ...     ...
# 10836                1.48          4.1 and up   10837
# 10837                 1.0          4.1 and up   10838
# 10838                 1.0          2.2 and up   10839
# 10839  Varies with device  Varies with device   10840
# 10840  Varies with device  Varies with device   10841
#
# [10841 rows x 14 columns]
# (10841, 14)
#         UserId  AppId  Rating   Timestamp
# 0            1     31     2.5  1260759144
# 1            1   1029     3.0  1260759179
# 2            1   1061     3.0  1260759182
# 3            1   1129     2.0  1260759185
# 4            1   1172     4.0  1260759205
# ...        ...    ...     ...         ...
# 99999      671   6268     2.5  1065579370
# 100000     671   6269     4.0  1065149201
# 100001     671   6365     4.0  1070940363
# 100002     671   6385     2.5  1070979663
# 100003     671   6565     3.5  1074784724
#
# [100004 rows x 4 columns]
# (100004, 4)

# %% [markdown]
# ### Data Preprocessing
# - #### Data Cleaning
#     - Feature Selection
#         - Let's choose the columns that we need for our recommendation
#         - by Removing columns that we don't need in each dataset

# %%
apps_data = apps_data.drop(columns=["Category", "Reviews", "Size", "Installs", "Type", "Price", "Content Rating", "Genres","Last Updated", "Current Ver", "Android Ver"])
display(apps_data)

users_data = users_data.drop(columns=["Timestamp"])
display(users_data)
# Out:
#                                                 App_Name  Rating  App_ID
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     4.1       1
# 1                                    Coloring book moana     3.9       2
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7       3
# 3                                  Sketch - Draw & Paint     4.5       4
# 4                  Pixel Draw - Number Art Coloring Book     4.3       5
# ...                                                  ...     ...     ...
# 10836                                   Sya9a Maroc - FR     4.5   10837
# 10837                   Fr. Mike Schmitz Audio Teachings     5.0   10838
# 10838                             Parkinson Exercices FR     NaN   10839
# 10839                      The SCP Foundation DB fr nn5n     4.5   10840
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     4.5   10841
#
# [10841 rows x 3 columns]
#         UserId  AppId  Rating
# 0            1     31     2.5
# 1            1   1029     3.0
# 2            1   1061     3.0
# 3            1   1129     2.0
# 4            1   1172     4.0
# ...        ...    ...     ...
# 99999      671   6268     2.5
# 100000     671   6269     4.0
# 100001     671   6365     4.0
# 100002     671   6385     2.5
# 100003     671   6565     3.5
#
# [100004 rows x 3 columns]

# %% [markdown]
# - #### Null values
# - Let's Check if the columns have null values in each dataset

# %%
headers_apps = ["App_Name", "Rating"]
for i in headers_apps:
    print(f"{i} = {len(apps_data[apps_data[i].isna()])}")
    
headers_users = ["UserId", "AppId", "Rating"]
for i in headers_users:
    print(f"{i} = {len(users_data[users_data[i].isna()])}")
# Out:
# App_Name = 0
# Rating = 1474
# UserId = 0
# AppId = 0
# Rating = 0

# %% [markdown]
# - As we see, Rating in apps dataset has null values
#     - we must drop them

# %%
# Remove any row conatins any null values
apps_data.dropna(axis=0, how='any', inplace=True)

# %% [markdown]
# - Let's check again

# %%
for i in headers_apps:
    print(f"{i} = {len(apps_data[apps_data[i].isna()])}")
# Out:
# App_Name = 0
# Rating = 0

# %% [markdown]
# - #### Duplicated values
# - Now let's find the duplicated apps names

# %%
duplicated_apps = apps_data[apps_data["App_Name"].duplicated()]["App_Name"]
len_duplicated = len(duplicated_apps)
print(duplicated_apps)
print(f"{len_duplicated} Duplicated values")
# Out:
# 229            Quick PDF Scanner + OCR FREE
# 236                                     Box
# 239                      Google My Business
# 256                     ZOOM Cloud Meetings
# 261               join.me - Simple Meetings
#                         ...
# 10715                    FarmersOnly Dating
# 10720    Firefox Focus: The privacy browser
# 10730                           FP Notebook
# 10753        Slickdeals: Coupons & Shopping
# 10768                                  AAFP
# Name: App_Name, Length: 1170, dtype: object
# 1170 Duplicated values

# %% [markdown]
# - Let's remove them

# %%
apps_data = apps_data.drop_duplicates(subset=["App_Name"])

# %% [markdown]
# - Let's check the duplicate after removing

# %%
duplicated_apps = apps_data[apps_data["App_Name"].duplicated()]["App_Name"]
len_duplicated = len(duplicated_apps)
print(f"{len_duplicated} Duplicated values")
# Out:
# 0 Duplicated values

# %% [markdown]
# - #### Outlier values
# - Let's check the values of Rating column
#     - the overall rating of apps
#     - the user's rating of app

# %%
app_rating = set(apps_data["Rating"])
users_rating= set(users_data["Rating"])
print(f"Overall Rating : {app_rating} ")
print(f"Users's Rating : {users_rating} ")
# Out:
# Overall Rating : {1.9, 2.6, 3.9, 4.3, 4.5, 4.1, 4.7, 4.4, 3.8, 4.2, 4.6, 3.2, 4.0, 5.0, 2.5, 3.5, 3.0, 2.0, 19.0, 4.9, 1.0, 1.5, 1.6, 2.1, 3.6, 3.1, 1.7, 1.2, 2.8, 2.7, 2.3, 2.2, 3.7, 3.3, 4.8, 1.8, 1.4, 2.9, 2.4, 3.4}
# Users's Rating : {0.5, 1.0, 2.0, 3.5, 2.5, 3.0, 4.0, 5.0, 4.5, 1.5}

# %% [markdown]
# - We notice that Rating column of apps dataset (Overall Rating) has a balance range from 1.0 to 5.0, but there is an outlier value we need to remove it -> 19.0
#
# - Users's dataset is fine

# %%
rowToRemove = 19.0
apps_data = apps_data[apps_data["Rating"] != 19.0]
display(apps_data)
# Out:
#                                                 App_Name  Rating  App_ID
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     4.1       1
# 1                                    Coloring book moana     3.9       2
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7       3
# 3                                  Sketch - Draw & Paint     4.5       4
# 4                  Pixel Draw - Number Art Coloring Book     4.3       5
# ...                                                  ...     ...     ...
# 10834                                      FR Calculator     4.0   10835
# 10836                                   Sya9a Maroc - FR     4.5   10837
# 10837                   Fr. Mike Schmitz Audio Teachings     5.0   10838
# 10839                      The SCP Foundation DB fr nn5n     4.5   10840
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     4.5   10841
#
# [8196 rows x 3 columns]

# %% [markdown]
# - Let's check again for Rating column in apps dataset

# %%
app_rating = set(apps_data["Rating"])
print(f"Overall Rating : {app_rating} ")
# Out:
# Overall Rating : {1.9, 2.6, 3.9, 4.3, 4.5, 4.1, 4.7, 4.4, 3.8, 4.2, 4.6, 3.2, 4.0, 5.0, 2.5, 3.5, 3.0, 2.0, 4.9, 1.0, 1.5, 1.6, 2.1, 3.6, 3.1, 1.7, 1.2, 2.8, 2.7, 2.3, 2.2, 3.7, 3.3, 4.8, 1.8, 1.4, 2.9, 2.4, 3.4}

# %% [markdown]
# ## Apriori Algorithm

# %% [markdown]
# - Before implementing the algorithm, we need to find the average of Rating columns, To filter the dataset based on it
# - filtering the two dataset to those rows whose rating more than the average
#
#     - We need the Apps of highest overall rating.
#     - and the Apps of highest user's rating .

# %%
def average_rating(rating):
    return sum(rating) / len(rating)

# %%
apps_rating = set(apps_data["Rating"])
users_rating = set(users_data["Rating"])

app_rating_avg = average_rating(apps_rating)
user_rating_avg = average_rating(users_rating)

print(f"The Average of App Rating is {app_rating_avg}")
print(f"The Average of User's Rating is {user_rating_avg}")
# Out:
# The Average of App Rating is 3.0923076923076924
# The Average of User's Rating is 2.75

# %%
apps_data = apps_data[apps_data['Rating'] > app_rating_avg].reset_index(drop=True)
users_data = users_data[users_data["Rating"] > user_rating_avg].reset_index(drop=True)
display(apps_data)
display(users_data)
# Out:
#                                                App_Name  Rating  App_ID
# 0        Photo Editor & Candy Camera & Grid & ScrapBook     4.1       1
# 1                                   Coloring book moana     3.9       2
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7       3
# 3                                 Sketch - Draw & Paint     4.5       4
# 4                 Pixel Draw - Number Art Coloring Book     4.3       5
# ...                                                 ...     ...     ...
# 7831                                      FR Calculator     4.0   10835
# 7832                                   Sya9a Maroc - FR     4.5   10837
# 7833                   Fr. Mike Schmitz Audio Teachings     5.0   10838
# 7834                      The SCP Foundation DB fr nn5n     4.5   10840
# 7835      iHoroscope - 2018 Daily Horoscope & Astrology     4.5   10841
#
# [7836 rows x 3 columns]
#        UserId  AppId  Rating
# 0           1   1029     3.0
# 1           1   1061     3.0
# 2           1   1172     4.0
# 3           1   1339     3.5
# 4           1   1953     4.0
# ...       ...    ...     ...
# 82165     671   5991     4.5
# 82166     671   5995     4.0
# 82167     671   6269     4.0
# 82168     671   6365     4.0
# 82169     671   6565     3.5
#
# [82170 rows x 3 columns]

# %% [markdown]
# - We will create a list of list
#     - List of 100 length (initially) for 100 Users
#     - Nested List of Apps of each user

# %%
record = []
for i in range(1, 101):
    user_row = users_data[users_data["UserId"] == i]
    apps = [apps_data[apps_data["App_ID"] == j]["App_Name"].values[0] for j in user_row["AppId"] if not apps_data[apps_data["App_ID"] == j].empty]
    record.append(apps)
record
# Out:
# [['SUMMER SONIC app',
#   'Nubank',
#   'Citi Mobile®',
#   'My Chakra Meditation 2',
#   'TEKKEN™',
#   'LEGO® Juniors Create & Cruise',
#   'codeSpark Academy & The Foos',
#   'Motorola FM Radio'],
#  ['Kids Paint Free - Drawing Fun',
#   'Photo Designer - Write your name with shapes',
#   'PIP Camera - PIP Collage Maker',
#   'Install images with music to make video without Net - 2018',
#   'Monster Truck Stunt 3D 2019',
#   'Ultimate F1 Racing Championship',
#   'CDL Practice Test 2018 Edition',
#   'Selfie Camera',
#   'Amazon Kindle',
#   'FBReader: Favorite Book Reader',
#   'Google Play Books',
#   'Recipes of Prophetic Medicine for free',
#   'Ebook Reader',
#   'English to Urdu Dictionary',
#   'Azpen eReader',
#   'Jobs in Alabama - Jobs in Alba',
#   'Myanmar 2D/3D',
#   'ATI Cargoes and Transportation',
#   'TurboScan: scan documents and receipts in PDF',
#   'Crew - Free Messaging and Scheduling',
#   'Invoice & Time Tracking - Zoho',
#   'Start Meeting',
#   'Skype for Business for Android',
#   'Verify - Receipts & Expenses',
#   'GANMA! - All original stories free of charge for all original comics',
#   '漫咖 Comics - Manga,Novel and Stories',
#   'Google Chrome: Fast & Secure',
#   'Contacts',
#   'Call Free – Free Call',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'Who',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'Telegram',
#   'Google Duo - High Quality Video Calls',
#   'GMX Mail',
#   '2ndLine - Second Phone Number',
#   'K-9 Mail',
#   'All Email Providers',
#   'Match™ Dating - Meet Singles',
#   'Black People Meet Singles Date',
#   'stranger chat - anonymous chat',
#   'Stranger Chat & Date',
#   'Free Dating & Flirt Chat - Choice of Love',
#   'NoBuffDating - Free Dating App',
#   'BBWCupid - BBW Dating App',
#   'TryDate - Free Online Dating App, Chat Meet Adults',
#   'Sky People (SPI): A secure blind date through authentication by Seoul National University',
#   'Sweet mi - unlimited hunnam hunting blind date',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'Hitwe - meet people and chat',
#   'A hundred',
#   'Awake Dating',
#   'Monster Truck Driver & Racing'],
#  ['REG - Check the regnumber, find information about Swedish vehicles',
#   'Selfie Camera',
#   'MailChimp - Email, Marketing Automation',
#   'Verify - Receipts & Expenses',
#   'Marvel Unlimited',
#   'Cricket Visual Voicemail',
#   'NoBuffDating - Free Dating App',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'Hitwe - meet people and chat',
#   'A hundred',
#   'Learn English from Persian: Persian to English',
#   'GRE Prep & Practice by Magoosh',
#   'Google Play Games',
#   'hellofood - Food Delivery',
#   'Dairy Queen',
#   'Instacart: Grocery Delivery',
#   'Buttocks and Abdomen',
#   'Couch to 5K by RunDouble',
#   'Safeway',
#   'Bowmasters',
#   'Candy Smash',
#   'Myntra Online Shopping App',
#   'Rossmann PL',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Urban Outfitters',
#   'Pretty Makeup, Beauty Photo Editor & Snappy Camera',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'Trello',
#   'B-Messenger Video Chat',
#   'Surah Al-Waqiah',
#   'AU Students Zone (Result 2016)',
#   'Audio Murli Glossary For BK',
#   'FlashLight HD LED Pro',
#   'Free Poker Games : Downtown Casino - Texas Holdem'],
#  ['Kids Paint Free - Drawing Fun',
#   'Easy Origami Ideas',
#   'Colors of white in Urdu',
#   'E-Book Read - Read Book for free',
#   'Google Play Books',
#   'Ancestry',
#   'Azpen eReader',
#   'Microsoft Remote Desktop',
#   'Verify - Receipts & Expenses',
#   'Funny Jokes and Stories 2018',
#   'Contacts',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'Who',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'My Vodacom SA',
#   '2ndLine - Second Phone Number',
#   'Safest Call Blocker',
#   'RocketDial Dialer & Contacts',
#   'Whoscall - Caller ID & Block',
#   'SolMail - All-in-One email app',
#   'USA Singles Meet, Match and Date Free - Date',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'JustSayHi- Dating App. Chat & Meet Singles Nearby',
#   'WannaMeet – Dating & Chat App',
#   'Girls Live Chat - Free Text & Video Chat',
#   'Awake Dating',
#   'Pluto TV - It’s Free TV',
#   'AMC Theatres',
#   'DramaFever: Stream Asian Drama Shows & Movies',
#   'Crackle - Free TV & Movies',
#   'VH1',
#   'DroidAdmin for Android - Advice',
#   'Name days',
#   'PTI Flex Maker, Photo Frame Editor & Songs 2018',
#   'vide-greniers.org',
#   'Quake & Volcanoes: 3D Globe of Volcanic Eruptions',
#   'Prosperity',
#   "Picktrainer: India's largest photo contest app",
#   'Goldstar: Live Event Tickets',
#   'Banorte Movil',
#   'Zenith Bank Mobile App',
#   'Bank of Brazil',
#   'FREE Stock Market Trading Tips',
#   'MetaTrader 4',
#   'E*TRADE Mobile',
#   'Grubhub: Food Delivery',
#   'Chick-fil-A',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   "Domino's Pizza USA",
#   'Dr. Oetker recipe ideas',
#   'SUBWAY®',
#   'Dairy Queen',
#   'SarashpazPapion (Cooking with Chef Bowls)',
#   'Little Caesars',
#   'My Recipes Cookbook : RecetteTek',
#   'Healthy Recipes Free',
#   'ChefTap Recipes & Grocery List',
#   '50 Healthy Slow Cooker Recipes',
#   'Yummly Recipes & Shopping List',
#   'Home Workout - No Equipment',
#   'Step Counter - Calorie Counter',
#   'Lose Belly Fat in 30 Days - Flat Stomach',
#   'Step Counter - Pedometer Free & Calorie Counter',
#   'Fat Burning Workout - Home Weight lose',
#   'Runtastic Running App & Mile Tracker',
#   'Nike+ Run Club',
#   'BetterMe: Weight Loss Workouts',
#   'Six Packs for Man–Body Building with No Equipment',
#   'Running Distance Tracker +',
#   'Keep Trainer - Workout Trainer & Fitness Coach',
#   'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#   'Yoga - Track Yoga',
#   'Relax with Andrew Johnson Lite',
#   'Simple Habit Meditation',
#   'Fertility Friend Ovulation App',
#   'Zombies, Run! 5k Training (Free)',
#   'Tracks',
#   'YAZIO Calorie Counter, Nutrition Diary & Diet Plan',
#   'Technutri - calorie counter, diet and carb tracker',
#   'My Diet Diary Calorie Counter',
#   'Super Funny Ringtones 2018 🔔',
#   'Safeway',
#   'Pou',
#   'PAC-MAN',
#   'Hustle Castle: Fantasy Kingdom',
#   'Doodle Jump',
#   'TEKKEN™',
#   'diep.io',
#   'Metal Soldiers 2',
#   'Jewels classic Prince',
#   'Dog Run - Pet Dog Simulator',
#   'Jewels Crush- Match 3 Puzzle',
#   'Mahjong',
#   'Super ABC! Learning games for kids! Preschool apps',
#   'Puzzle Kids - Animals Shapes and Jigsaw Puzzles',
#   'Educational Games for Kids',
#   'DisneyNOW – TV Shows & Games',
#   'Intellijoy Early Learning Academy',
#   'Leo and Tig',
#   'School of Dragons',
#   'Cutie Cubies',
#   'My Little Princess : Stores',
#   'Sago Mini Big City',
#   'Cars: Lightning League',
#   "Snoopy's Town Tale - City Building Simulator",
#   'LEGO® Juniors Create & Cruise',
#   'Paw Patrol by ShuffleCards',
#   'Plants vs. Zombies™ Heroes',
#   'L.O.L. Surprise Ball Pop',
#   'Equestria Girls',
#   'Monster High™ Minis Mania',
#   'Shopkins World!',
#   'Toy Guitar with songs for kids',
#   'Endless Numbers',
#   'Crazy Colors: Bubbles Matching',
#   'SweetLand — Family Board Game',
#   "Dr. Panda & Toto's Treehouse",
#   'Journal Club: Medicine',
#   'Super Hearing Secret Voices Recorder PRO',
#   'Pocket Lab Values',
#   'Whist - Tinnitus Relief',
#   'Super Hearing Super Ear Amplifier',
#   'Official NBSTSA CST Exam Prep',
#   'Nursing Central',
#   'Tinnitus Alleviator',
#   'Snapchat',
#   'Dating App, Flirt & Chat : W-Match',
#   'Shopee: No.1 Online Shopping',
#   'Family Dollar',
#   'Flipkart Online Shopping App',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Blidz - Hunt Free Deals On Trending Items!',
#   'FidMe Loyalty Cards & Deals at Grocery Supermarket',
#   'ShopSavvy Barcode & QR Scanner',
#   'FreePrints – Free Photos Delivered',
#   'HD Camera',
#   'Wondershare PowerCam',
#   'KVAD Camera +: Selfie, Photo Filter, Grids',
#   'Phogy, 3D Camera',
#   'Photo Effects Pro',
#   'No Crop & Square for Instagram',
#   'FIFA - Tournaments, Soccer News & Live Scores',
#   'beIN SPORTS TR',
#   'ESPN Fantasy Sports',
#   'Championat',
#   'Golfshot: Golf GPS + Tee Times',
#   'GolfLogix GPS + Putt Breaks',
#   'Golfshot Plus: Golf GPS',
#   'Tennis News and Scores',
#   'Sports Alerts - NFL edition',
#   'trivago: Hotels & Travel',
#   'CityMaps2Go Plan Trips Travel Guide Offline Maps',
#   'Urbanspoon Restaurant Reviews',
#   'SPG: Starwood Hotels & Resorts',
#   'iWnn IME for Nexus',
#   'Calculator - free calculator ,multi calculator app',
#   'Clear',
#   'HTC Lock Screen'],
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'PIP Camera - PIP Collage Maker',
#   'Beauty Selfie Camera',
#   'E-Book Read - Read Book for free',
#   'FBReader: Favorite Book Reader',
#   'Genius Scan - PDF Scanner',
#   'My Tele2',
#   'Cricket Visual Voicemail',
#   'Who',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'GMX Mail',
#   'RocketDial Dialer & Contacts',
#   'stranger chat - anonymous chat',
#   'Sweet mi - unlimited hunnam hunting blind date',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'FERZU - Furries Social Network',
#   'AMC Theatres',
#   'VH1',
#   'PTI Flex Maker, Photo Frame Editor & Songs 2018',
#   'Simple Recipes',
#   'Pizza Hut',
#   'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#   'Calorie Counter - MyNetDiary',
#   'Super Funny Ringtones 2018 🔔',
#   'Flow Free',
#   'Bowmasters',
#   'Color Road',
#   'Tomb of the Mask',
#   'Metal Soldiers 2',
#   'School of Dragons',
#   'AnatomyMapp',
#   'Acupuncture Assistant',
#   'Epocrates Plus',
#   'Family Dollar',
#   'Myntra Online Shopping App',
#   'SnipSnap Coupon App',
#   'Urban Outfitters',
#   'No Crop & Square for Instagram',
#   'Speed Boat Racing',
#   'Hostelworld: Hostels & Cheap Hotels Travel App',
#   'Fancy Widgets',
#   'ARY NEWS',
#   'Disney Magic Timer by Oral-B',
#   'learn c in hindi',
#   'C Programs Handbook',
#   'Learn Basic C - For Beginners',
#   'Magic Tiles - TWICE Edition (K-Pop)',
#   'The Maze Runner',
#   'Weather & Radar Pro - Ad-Free',
#   'AE Sudoku',
#   'Surah Al-Waqiah',
#   'UniFi',
#   'AU Students Zone (Result 2016)',
#   'Dance On Mobile',
#   'INTERACTIVE CALCULUS FOR MATHS AND PHYSICS',
#   'BackCountry Navigator TOPO GPS PRO',
#   'BusyBox Pro',
#   'BK Formula Calculator',
#   'Audio Murli Glossary For BK',
#   'NOOK Audiobooks',
#   'DG Video Editor',
#   'Euro Truck Driver (Simulator)',
#   'Free Poker Games : Downtown Casino - Texas Holdem'],
#  ['Sweet Selfie Beauty Camera',
#   'WannaMeet – Dating & Chat App',
#   'AMC Theatres',
#   'Delivery yogi.',
#   'Lose Belly Fat in 30 Days - Flat Stomach',
#   'Fitbit',
#   'BetterMe: Weight Loss Workouts',
#   'Coloring & Learn',
#   'Henry Danger Crime Warp',
#   'SweetLand — Family Board Game',
#   'BP Journal - Blood Pressure Diary',
#   'TelaDoc',
#   "ROMWE - Women's Fashion",
#   'Blidz - Hunt Free Deals On Trending Items!',
#   'Zappos – Shoe shopping made simple',
#   'SuperPhoto - Effects & Filters',
#   'Hostelworld: Hostels & Cheap Hotels Travel App',
#   'Fraction Calculator Plus Free',
#   'CA UIM Mobile',
#   'ARK: Survival Evolved',
#   'FlashLight HD LED Pro',
#   'DG UPnP Player Free',
#   'Super Dr. Parking 3D'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Kids Paint Free - Drawing Fun',
#   'Logo Maker - Small Business',
#   'Pink Silver Bow Keyboard Theme',
#   'Easy Origami Ideas',
#   'How To Color Disney Princess - Coloring Pages',
#   'Beauty Selfie Camera',
#   'Selfie Camera',
#   'Colors of white in Urdu',
#   'E-Book Read - Read Book for free',
#   'English Grammar Complete Handbook',
#   'Call Blocker',
#   'Microsoft Remote Desktop',
#   'Marvel Unlimited',
#   'Funny Jokes and Stories 2018',
#   'think Comics',
#   'Firefox Browser fast & private',
#   'ZenUI Dialer & Contacts',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'Who',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'GMX Mail',
#   'My Vodacom SA',
#   'stranger chat - anonymous chat',
#   'Adult Dating - AdultFinder',
#   'TryDate - Free Online Dating App, Chat Meet Adults',
#   'USA Singles Meet, Match and Date Free - Date',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'Hitwe - meet people and chat',
#   'JustSayHi- Dating App. Chat & Meet Singles Nearby',
#   'FERZU - Furries Social Network',
#   'Girls Live Chat - Free Text & Video Chat',
#   'English Grammar Test',
#   'Monster Truck Driver & Racing',
#   'Elevate - Brain Training Games',
#   'SAT Vocabulary',
#   'Hulu: Stream TV, Movies & more',
#   'Goldstar: Live Event Tickets',
#   'Banorte Movil',
#   'Zenith Bank Mobile App',
#   'GCash - Buy Load, Pay Bills, Send Money',
#   'FREE Stock Market Trading Tips',
#   'Seeking Alpha',
#   'E*TRADE Mobile',
#   'Current debit card and app made for teens',
#   'Chick-fil-A',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   'Dairy Queen',
#   'Healthy Recipes Free',
#   'Recipe Keeper',
#   '50 Healthy Slow Cooker Recipes',
#   'Kitchen Stories - Recipes & Cooking',
#   'Fat Burning Workout - Home Weight lose',
#   'Sleep Sounds',
#   'Runtastic Running App & Mile Tracker',
#   'Calorie Counter - MyFitnessPal',
#   'Six Packs for Man–Body Building with No Equipment',
#   'Running Distance Tracker +',
#   'Keep Trainer - Workout Trainer & Fitness Coach',
#   'PumpUp — Fitness Community',
#   'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#   'My Days - Ovulation Calendar & Period Tracker ™',
#   'Zombies, Run! 5k Training (Free)',
#   'Tracks',
#   'YAZIO Calorie Counter, Nutrition Diary & Diet Plan',
#   '10 Best Foods for You'],
#  ['Art Drawing Ideas',
#   'Install images with music to make video without Net - 2018',
#   'Monster Truck Stunt 3D 2019',
#   'Selfie Camera',
#   'Microsoft Remote Desktop',
#   'Verify - Receipts & Expenses',
#   'Marvel Unlimited',
#   'Cricket Visual Voicemail',
#   'All Email Providers',
#   'Single Parent Meet #1 Dating',
#   'NoBuffDating - Free Dating App',
#   'A hundred',
#   'Learn English with Aco',
#   'Pluto TV - It’s Free TV',
#   'Chick-fil-A',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   'Dairy Queen',
#   'My Recipes Cookbook : RecetteTek',
#   '50 Healthy Slow Cooker Recipes',
#   'Step Counter - Calorie Counter',
#   'Lose Belly Fat in 30 Days - Flat Stomach',
#   'Step Counter - Pedometer Free & Calorie Counter',
#   'Fat Burning Workout - Home Weight lose',
#   'Running Distance Tracker +',
#   'PumpUp — Fitness Community',
#   'Calorie Counter - MyNetDiary',
#   'Wall Decorating Ideas',
#   'Wifi Test',
#   'Chictopia',
#   'PAC-MAN',
#   'Love Balls',
#   'Color Road',
#   'Metal Soldiers 2',
#   'Candy Smash',
#   'Cars: Lightning League',
#   'Frozen Free Fall',
#   'A Manual of Acupuncture',
#   'Blood Pressure Log - MyDiary',
#   'CVS Caremark',
#   'Mayo Clinic',
#   'Golden telegram',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Urban Outfitters',
#   'FreePrints – Free Photos Delivered',
#   'Pretty Makeup, Beauty Photo Editor & Snappy Camera',
#   'No Crop & Square for Instagram',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'SNCF',
#   'Disney Magic Timer by Oral-B',
#   'CL Mobile - Classifieds for Craigslist',
#   'codeEazy - C/C++/JAVA',
#   'Discord - Chat for Gamers',
#   'What was I in my Past Life',
#   '5 Minute Ab Workouts',
#   'Abs workout - 21 Day Fitness Challenge',
#   'Weather & Radar Pro - Ad-Free',
#   'Photo Compress 2.0 - Ad Free',
#   'Adobe Premiere Clip',
#   'AE Sudoku',
#   'Blur Image - DSLR focus effect',
#   'Who am I? (Biblical)',
#   'Weaphones™ Gun Sim Free Vol 1',
#   'UniFi',
#   'Rivals at War: Firefight',
#   'Undertale AU Amino',
#   'AU Students Zone (Result 2016)',
#   'British Columbia Tourist Places (Guide)',
#   'Audio Murli Glossary For BK',
#   'Cb browser',
#   'ARK: Survival Evolved',
#   'FlashLight HD LED Pro',
#   'China Town Auto Theft 2',
#   'Super Dr. Parking 3D'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Photo Designer - Write your name with shapes',
#   'Harley Quinn wallpapers HD',
#   'How to draw Ladybug and Cat Noir',
#   'Install images with music to make video without Net - 2018',
#   'Marvel Unlimited',
#   'Black People Meet Singles Date',
#   'NoBuffDating - Free Dating App',
#   'Adult Dating - AdultFinder',
#   'A hundred',
#   'Live Talk - Free Text and Video Chat',
#   'Capitec Remote Banking',
#   "McDonald's",
#   'Pregnancy Tracker',
#   'Period Tracker',
#   'H&M',
#   'Granny',
#   'Flow Free',
#   'Bowmasters',
#   'Tomb of the Mask',
#   'Candy Smash',
#   'Monster High™ Minis Mania',
#   'Paramedic Protocol Provider',
#   'Pocket Lab Values',
#   'AnatomyMapp',
#   'Muscle Premium - Human Anatomy, Kinesiology, Bones',
#   'With Helper Pro Pill Reminder',
#   'A Manual of Acupuncture',
#   'Blue CareOnDemand',
#   'Golden telegram',
#   'Urban Outfitters',
#   'Flickr'],
#  ['Monster Truck Stunt 3D 2019',
#   'Free Books - Spirit Fanfiction and Stories',
#   'Marvel Unlimited',
#   'My Tele2',
#   'Firefox Browser fast & private',
#   'Hitwe - meet people and chat',
#   'Lumosity: #1 Brain Games & Cognitive Training App',
#   'Goldstar: Live Event Tickets',
#   'Bank of Brazil',
#   'MetaTrader 4',
#   'Chick-fil-A',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   "Domino's Pizza USA",
#   'Dairy Queen',
#   'Healthy Recipes Free',
#   'Running Distance Tracker +',
#   'Period Tracker',
#   'Yongqing fast search',
#   'Bathroom Decorating Ideas',
#   'Wedding LookBook by The Knot',
#   'Hill Climb Racing',
#   'Garena Free Fire',
#   'Ninja Dash - Ronin Jump RPG',
#   'Migraine Buddy - The Migraine and Headache tracker',
#   'Nursing Central',
#   'tökr',
#   'Golden telegram',
#   'InstaBeauty -Makeup Selfie Cam',
#   'Garden Photo Frames - Garden Photo Editor',
#   'Pencil Photo Sketch-Sketching Drawing Photo Editor',
#   'Pretty Makeup, Beauty Photo Editor & Snappy Camera',
#   'Mega Photo',
#   'SuperPhoto - Effects & Filters',
#   'Mercato foot by Maxifoot'],
#  ['Monster Truck Stunt 3D 2019',
#   'Filters for B Live',
#   'eBoox: book reader fb2 epub zip',
#   'Verify - Receipts & Expenses',
#   'GRE Prep & Practice by Magoosh',
#   'BET NOW - Watch Shows',
#   'Events High - Meet Your City!',
#   'Chef - Recipes & Cooking',
#   'ooVoo Video Calls, Messaging & Stories',
#   'Urban Outfitters',
#   'Tiger Live Wallpaper',
#   'AU Students Zone (Result 2016)',
#   'MedM Blood Pressure'],
#  ['Invoice & Time Tracking - Zoho',
#   'ChatVideo Meet new people',
#   'Learn English from Persian: Persian to English',
#   'English with Lingualeo',
#   'PayPal',
#   'Recipes Pastries and homemade pies More than 500 recipes for pastries',
#   'Healthy Recipes Free',
#   'Instacart: Grocery Delivery',
#   'Jungle Marble Blast',
#   'Anatomy & Physiology Vocabulary Exam Review App',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'Brightest LED Flashlight',
#   'Fancy Widgets',
#   'Dropbox',
#   'LA Times: Your California News',
#   'HuffPost - News',
#   'SmartNews: Breaking News Headlines',
#   '乗換NAVITIME\u3000Timetable & Route Search in Japan Tokyo',
#   'Yandex.Transport',
#   'Subway Terminator: Smarter Subway',
#   'Yandex.Trains',
#   'NAVITIME Bus Transit JAPAN',
#   'hum app',
#   'aa',
#   'Dog Sim Online: Raise a Family',
#   'Build a Bridge!',
#   'Revita.bg'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Selfie Camera',
#   'Verify - Receipts & Expenses',
#   'Marvel Unlimited',
#   'Cricket Visual Voicemail',
#   'Xperia Link™',
#   'Sugar Mommas Dating And Single Search',
#   'NoBuffDating - Free Dating App',
#   'Meet4U - Chat, Love, Singles!',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'CBS - Full Episodes & Live TV',
#   'VH1',
#   'Events High - Meet Your City!',
#   'Lose Belly Fat in 30 Days - Flat Stomach',
#   'Metal Soldiers 2',
#   'Epocrates Plus',
#   'Golden telegram',
#   'Amino: Communities and Chats',
#   'Zappos – Shoe shopping made simple',
#   'Urban Outfitters',
#   'FreePrints – Free Photos Delivered',
#   'EyeEm - Camera & Photo Filter',
#   'No Crop & Square for Instagram',
#   'Hostelworld: Hostels & Cheap Hotels Travel App',
#   'SNCF',
#   'Calculator - free calculator ,multi calculator app',
#   'Water Droplets Keyboard Theme',
#   "It's open.",
#   'Magic Tiles - TWICE Edition (K-Pop)',
#   'Niche: College, K-12, and Neighborhood Search',
#   'AB Click2Shop',
#   '5 Minute Ab Workouts',
#   'Adobe Premiere Clip',
#   'British Columbia Tourist Places (Guide)',
#   'Audio Murli Glossary For BK',
#   'FlashLight HD LED Pro'],
#  ['Chick-fil-A',
#   'Bowmasters',
#   'Toca Kitchen 2',
#   'Free Hypnosis',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Hostelworld: Hostels & Cheap Hotels Travel App',
#   'Funny Ringtones',
#   'Vegetable Fun',
#   'РИА Новости'],
#  ['Pixel Draw - Number Art Coloring Book',
#   'Paper flowers instructions',
#   'Kids Paint Free - Drawing Fun',
#   'Learn To Draw Kawaii Characters',
#   'Photo Designer - Write your name with shapes',
#   'Logo Maker - Small Business',
#   'HD Mickey Minnie Wallpapers',
#   'Art Drawing Ideas',
#   'Easy Origami Ideas',
#   'Paint Splash!',
#   'Install images with music to make video without Net - 2018',
#   'Monster Truck Stunt 3D 2019',
#   'PakWheels: Buy & Sell Cars',
#   'auto fines',
#   'Natural recipes for your beauty',
#   'Selfie Camera',
#   'Sweet Selfie Beauty Camera',
#   'Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#   'Sticker Camera - Selfie Filters, Beauty Camera',
#   'Cool Reader',
#   'Book store',
#   'FBReader: Favorite Book Reader',
#   'Recipes of Prophetic Medicine for free',
#   'ReadEra – free ebook reader',
#   'Ebook Reader',
#   'English translation from Bengali',
#   'Pdf Book Download - Read Pdf Book',
#   'Moon+ Reader',
#   'Easy Installer - Apps On SD',
#   'Quick PDF Scanner + OCR FREE',
#   'Genius Scan - PDF Scanner',
#   'Tiny Scanner - PDF Scanner App',
#   'Fast Scanner : Free PDF Scan',
#   'TurboScan: scan documents and receipts in PDF',
#   'Xero Accounting Software',
#   'Microsoft Remote Desktop',
#   'Verify - Receipts & Expenses',
#   'GANMA! - All original stories free of charge for all original comics',
#   'Manga - read Thai translation',
#   'The Vietnam Story - Fun Stories',
#   'Dragon Ball Wallpaper - Ringtones',
#   'DC Comics',
#   'Hangouts',
#   'Contacts',
#   'Browser 4G',
#   'Opera Browser: Fast and Secure',
#   'Who',
#   'Android Messages',
#   'Google Duo - High Quality Video Calls',
#   'Puffin Web Browser',
#   'GMX Mail',
#   'My Vodacom SA',
#   'Safest Call Blocker',
#   'CallApp: Caller ID, Blocker & Phone Call Recorder',
#   'K-9 Mail',
#   'All Email Providers',
#   'Vonage Mobile® Call Video Text',
#   'Free Dating App & Flirt Chat - Match with Singles',
#   'stranger chat - anonymous chat',
#   'Single Parent Meet #1 Dating',
#   'NoBuffDating - Free Dating App',
#   'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#   'USA Singles Meet, Match and Date Free - Date',
#   'Heart mill',
#   'Herpes Positive Singles Dating',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'Hitwe - meet people and chat',
#   'A hundred',
#   'Live Talk - Free Text and Video Chat',
#   'Girls Live Chat - Free Text & Video Chat',
#   'English Grammar Test',
#   'Monster Truck Driver & Racing',
#   'Learn English for beginners',
#   'Elevate - Brain Training Games',
#   'Lynda - Online Training Videos',
#   'GRE Prep & Practice by Magoosh',
#   'Free english course',
#   'Babbel – Learn Spanish',
#   'Mango Languages: Lovable Language Courses',
#   'Blinkist - Nonfiction Books',
#   'Pluto TV - It’s Free TV',
#   'Google Play Games',
#   'AMC Theatres',
#   'Animal Planet GO',
#   'VRV: Anime, game videos & more',
#   'Crunchyroll - Everything Anime',
#   'Investigation Discovery GO',
#   'Crackle - Free TV & Movies',
#   'VH1',
#   'FOX NOW - On Demand & Live TV',
#   'BET NOW - Watch Shows',
#   'Hulu: Stream TV, Movies & more',
#   'Univision NOW - Live TV and On Demand',
#   'LEGO® TV',
#   'Goldstar: Live Event Tickets',
#   'Freitas Auctioneer Official',
#   'Itau bank',
#   'Banorte Movil',
#   'Zenith Bank Mobile App',
#   'Google Pay',
#   'Bank of Brazil',
#   'Digit Save Money Automatically',
#   'Stash: Invest. Learn. Save.',
#   'MetaTrader 4',
#   'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO',
#   'Current debit card and app made for teens',
#   'Amex Mobile',
#   'Navy Federal Credit Union',
#   'Barclays US for Android',
#   'Cookpad - FREE recipe search makes fun cooking · musical making!',
#   'Frigo Magic: Easy recipe idea and anti-waste',
#   'Popeyes® App',
#   'Simple Recipes',
#   'Chick-fil-A',
#   'Starbucks',
#   "Domino's Pizza USA",
#   'Chef - Recipes & Cooking',
#   'HungerStation',
#   'Dr. Oetker recipe ideas',
#   'SONIC Drive-In',
#   'SUBWAY®',
#   'GialloZafferano: Recipes',
#   'Dairy Queen',
#   'OpenRice',
#   'SarashpazPapion (Cooking with Chef Bowls)',
#   'Little Caesars',
#   'Wendy’s – Food and Offers',
#   'My Recipes Cookbook : RecetteTek',
#   'Cookbook Recipes',
#   'ChefTap Recipes & Grocery List',
#   'Recipe Keeper',
#   '50 Healthy Slow Cooker Recipes',
#   'My CookBook Pro (Ad Free)',
#   'Yummly Recipes & Shopping List',
#   'Kitchen Stories - Recipes & Cooking',
#   'BigOven Recipes, Meal Planner, Grocery List & More',
#   'Postmates Food Delivery: Order Eats & Alcohol',
#   'Instacart: Grocery Delivery',
#   'Eat24 Food Delivery & Takeout',
#   'Pizza Hut',
#   'Caviar - Food Delivery',
#   'DoorDash - Food Delivery',
#   'Uber Eats: Local Food Delivery',
#   'Seamless Food Delivery/Takeout',
#   'TheFork - Restaurants booking and special offers',
#   'Step Counter - Calorie Counter',
#   'Lose Belly Fat in 30 Days - Flat Stomach',
#   'Pedometer - Step Counter Free & Calorie Burner',
#   'Pedometer',
#   'LG Health',
#   'Step Counter - Pedometer Free & Calorie Counter',
#   'Pedometer, Step Counter & Weight Loss Tracker App',
#   'Sportractive GPS Running Cycling Distance Tracker',
#   'Fat Burning Workout - Home Weight lose',
#   'Walking for Weight Loss - Walk Tracker',
#   'Abs Training-Burn belly fat',
#   'Aunjai i lert u',
#   'Garmin Connect™',
#   'Six Packs for Man–Body Building with No Equipment',
#   'Weight Watchers Mobile',
#   'Endomondo - Running & Walking',
#   'Running Distance Tracker +',
#   'Runkeeper - GPS Track Run Walk',
#   '8fit Workouts & Meal Planner',
#   'PumpUp — Fitness Community',
#   'Running Weight Loss Walking Jogging Hiking FITAPP',
#   'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#   'Period Tracker - Period Calendar Ovulation Tracker',
#   'Water Drink Reminder',
#   'Technutri - calorie counter, diet and carb tracker',
#   'Calorie Counter - MyNetDiary',
#   '10 Best Foods for You',
#   'My Diet Diary Calorie Counter',
#   'Apartments & Rentals - Zillow',
#   'Living Smart Home',
#   'Trulia Rent Apartments & Homes',
#   'Room planner: Interior & Floorplan Design for IKEA',
#   'Alfred Home Security Camera',
#   'House app: beautiful everyday ~',
#   'Wall Decorating Ideas',
#   'Best New Ringtones 2018 Free 🔥 For Android™',
#   'eBiblio',
#   'SAMSUNG RETAILMODE 2018',
#   'Chart - Myanmar Keyboard',
#   'ZenUI Safeguard',
#   'Safeway',
#   'H&M',
#   'justWink Greeting Cards',
#   'Been Together (Ad) - D-day',
#   'WedMeGood - Wedding Planner',
#   'Chictopia',
#   'Real Estate by Movoto',
#   'Housing-Real Estate & Property',
#   'Relax Rain ~ Rain Sounds',
#   '7 Day Food Journal Challenge',
#   'Pou',
#   'Block Puzzle Classic Legend !',
#   '8 Ball Pool',
#   'Granny',
#   'Candy Crush Jelly Saga',
#   'Zombie Catchers',
#   'Garena Free Fire',
#   'Jungle Marble Blast',
#   'Block Craft 3D: Building Simulator Games For Free',
#   'Farm Fruit Pop: Party Time',
#   'Love Balls',
#   'Tomb of the Mask',
#   'Hole.io',
#   'Offroad Outlaws',
#   'Final Fantasy XV: A New Empire',
#   'The Room: Old Sins',
#   'Might & Magic: Elemental Guardians',
#   'Game of Thrones: Conquest™',
#   'Sweet Fruit Candy',
#   'Extreme Match',
#   'Once Upon a Tower',
#   'TEKKEN™',
#   'diep.io',
#   'Arrow.io',
#   'BEYBLADE BURST app',
#   'Metal Soldiers 2',
#   'Runner 3d like',
#   'Dinosaur Simulator: Dino World',
#   'Marble Woka Woka 2018 - Bubble Shooter Match 3',
#   'Super Jabber Jump 3',
#   'Coloring & Learn',
#   'Candy Smash',
#   'DisneyNOW – TV Shows & Games',
#   'Toddler Kids Puzzles PUZZINGO',
#   'LEGO® Juniors Create & Cruise',
#   'Ninja Dash - Ronin Jump RPG',
#   'L.O.L. Surprise Ball Pop',
#   'Monster High™ Minis Mania',
#   'codeSpark Academy & The Foos',
#   'Checkers ✔️',
#   'Crazy Colors: Bubbles Matching',
#   'Pino chess',
#   'SweetLand — Family Board Game',
#   'Tee and Mo Bath Time Free',
#   'ABCmouse.com',
#   'My Little Pony Celebration',
#   'Card Wars - Adventure Time',
#   'Journal Club: Medicine',
#   'Menstrual Calendar Premium',
#   'Whist - Tinnitus Relief',
#   'With Helper Pro Pill Reminder',
#   'A Manual of Acupuncture',
#   'palmPEDi: Pediatric Tape',
#   'Doctor On Demand',
#   'Youper - AI Therapy',
#   'ClearCareGo Caregiver',
#   'Pregnancy Calculator and Tracker app',
#   'Official NBSTSA CST Exam Prep',
#   'Johns Hopkins Guides ABX...',
#   'e-Anatomy',
#   'Wide address pocket prep',
#   'Nursing Central',
#   'abeoCoder',
#   'JH Blood Pressure Monitor',
#   'KBA-EZ Health Guide',
#   'Basics of Orthopaedics',
#   'Blue CareOnDemand',
#   'The Video Messenger App',
#   'Golden telegram',
#   'Amino: Communities and Chats',
#   'MobilePatrol Public Safety App',
#   'Quora',
#   'MeetMe: Chat & Meet New People',
#   'Tapatalk - 100,000+ Forums',
#   'Dating App, Flirt & Chat : W-Match',
#   'Lotte Home Shopping LOTTE Homeshopping',
#   'Carousell: Snap-Sell, Chat-Buy',
#   "ROMWE - Women's Fashion",
#   'Flipkart Online Shopping App',
#   "Sam's Club: Wholesale Shopping & Instant Savings",
#   'SnipSnap Coupon App',
#   'Checkout 51: Grocery coupons',
#   'Shopkick: Free Gift Cards, Shop Rewards & Deals',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Groupon - Shop Deals, Discounts & Coupons',
#   'LivingSocial - Local Deals',
#   'Photo frame',
#   'InstaSize Photo Filters & Collage Editor',
#   'SuperPhoto - Effects & Filters',
#   'Photo Effects Pro',
#   'No Crop & Square for Instagram',
#   'Pixgram- video photo slideshow',
#   'Snapseed',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'BeSoccer - Soccer Live Score',
#   'All Football - Latest News & Videos',
#   'Eurosport',
#   'ESPN Fantasy Sports',
#   'GollerCepte Live Score',
#   'Hovercraft Racer',
#   'Speed Boat Racing',
#   'Goal Live Scores',
#   'MLB Ballpark',
#   'GolfNow: Tee Time Deals at Golf Courses, Golf GPS',
#   'Live Golf Scores - US & European Golf',
#   'GolfLogix GPS + Putt Breaks',
#   'DraftKings - Daily Fantasy Sports',
#   'Live Tennis Rankings / LTR',
#   'Tennis News and Scores',
#   'Thuuz Sports',
#   'trivago: Hotels & Travel',
#   'Trip by Skyscanner - City & Travel Guide',
#   'CityMaps2Go Plan Trips Travel Guide Offline Maps',
#   'Google Street View',
#   'AirAsia',
#   'Despegar.com Hotels and Flights',
#   '2GIS: directory & navigator',
#   'Where to travel - ticket. hotel. train ticket. car ticket. travel. tickets',
#   'SPG: Starwood Hotels & Resorts',
#   'myMetro',
#   'File Manager -- Take Command of Your Files Easily',
#   'HTC Lock Screen',
#   'Gboard - the Google Keyboard',
#   'Google Korean Input',
#   "I Can't Wake Up! Alarm Clock",
#   'Brightest LED Flashlight',
#   'Fraction Calculator Plus Free',
#   'Calculator Plus Free',
#   'Calculator ++',
#   'Hideman VPN',
#   'Fast Secure VPN',
#   'Hotspot Shield Free VPN Proxy & Wi-Fi Security',
#   'Smart Keyboard Trial',
#   'CM Launcher 3D - Theme, Wallpapers, Efficient',
#   '4K Wallpapers and Ultra HD Backgrounds',
#   'Hola Launcher- Theme,Wallpaper',
#   'Kairo XP (for HD Widgets)',
#   'Koi Free Live Wallpaper',
#   'My Claro Peru',
#   'ASUS SuperNote',
#   'HTC Calendar',
#   'Google Calendar',
#   'Yandex.Disk',
#   'Loop - Habit Tracker',
#   'Planner Pro-Personal Organizer',
#   'Todoist: To-do lists for task management & errands',
#   'Easy Voice Recorder',
#   'Google Sheets',
#   'ColorNote Notepad Notes',
#   'New Calendar',
#   'Unclouded - Cloud Manager',
#   'Amazon Drive',
#   'My baby Piano',
#   'Family Album Mitene: Private Photo & Video Sharing',
#   'Feed Baby - Baby Tracker',
#   'MyRadar NOAA Weather Radar',
#   'Free live weather on screen',
#   'Weather Crave',
#   'YouCut - Video Editor & Video Maker, No Watermark',
#   'SVT Play',
#   'Nigeria News NAIJ.com',
#   'Dailyhunt (Newshunt) - Latest News, Viral Videos',
#   'Bloomberg: Market & Financial News',
#   'Haystack TV: Local & World News - Free',
#   'ABC News - US & World News',
#   'HuffPost - News',
#   'Map Coordinates',
#   'SBB Mobile',
#   'Subway Terminator: Smarter Subway',
#   'National Rail Enquiries',
#   'Color by Number - Draw Sandbox Pixel Art',
#   'Basketball Stars',
#   'Cat Sim Online: Play with Cats',
#   'Disney Magic Timer by Oral-B',
#   'B-Messenger Video Chat',
#   'BIGO LIVE - Live Stream',
#   'Cardi B Wallpaper',
#   'A & B Taxi',
#   'C4droid - C/C++ compiler & IDE',
#   'CL Mobile - Classifieds for Craigslist',
#   'C Programs and Reference',
#   'All C Programs',
#   'Clean Master- Space Cleaner & Antivirus',
#   'Learn C Programming (Examples) (OFFLINE)',
#   'Expert C Programming - Learn C Coding Easily',
#   'Batmobile™ R/C Controller',
#   'C Pattern Programs Free',
#   'C Programs Handbook',
#   '101 C Programming Problems',
#   'C Examples',
#   'Dubsmash',
#   'Discord - Chat for Gamers',
#   'Car Parking Game 3D - Real City Driving Challenge',
#   'Moto LED for Moto X & E [Root]',
#   'MHD F-Series',
#   'F-Gas Solutions',
#   'My G:',
#   'What was I in my Past Life',
#   'Solitaire!',
#   'LINE I Love Coffee',
#   'Niche: College, K-12, and Neighborhood Search',
#   'M-Files',
#   'Super Hero M Craft Run',
#   'M Theme - Dark Green Icon Pack',
#   "Rope'n'Fly 4",
#   'Cops N Robbers 2',
#   "Rope'n'Fly 3 - Dusk Till Dawn",
#   "Lock 'n' Roll Pro - Ad Free",
#   'O Multiple - App Cloner, Duals APP, tarallel',
#   'pretty Easy privacy p≡p',
#   'Learn R - Programming Concepts',
#   'Offroad Pickup Truck S',
#   "Ludo - Don't get angry",
#   'T-Mobile SyncUP DRIVE',
#   'Kicker U Lite',
#   'V for Voodoo',
#   'Sin City Crime Simulator V - Gangster',
#   'Mike V: Skateboard Party PRO',
#   'Words With Friends Classic',
#   'WIFI WPS WPA TESTER',
#   'Zaatar w Zeit',
#   'Zapya - File Transfer, Sharing',
#   'Daily Ab Workout - Core & Abs Fitness Exercises',
#   'AB Click2Shop',
#   '5 Minute Ab Workouts',
#   'AB Screen Recorder',
#   'Smart Air Conditioner',
#   'AC Remote Control',
#   'Weather & Radar Pro - Ad-Free',
#   'Digital Clock : Simple, Tiny, Ad-free Desk Clock.',
#   'Adobe Premiere Clip',
#   'AE Bingo: Offline Bingo Games',
#   'AE Video Poker',
#   'AE Archer',
#   'Camera Pro',
#   'Auto Dslr Photo Effect : Auto Focus Effect',
#   'Gun Strike Shoot',
#   'AI Sight',
#   'AJ Rafael Music Lessons',
#   'AK-47 Assault Rifle',
#   'Alabama DMV Permit Test - AL',
#   'Al-Quran 30 Juz free copies',
#   'Quran for Android',
#   'What Am I? - Brain Teasers',
#   'Who am I? (Biblical)',
#   'Legend - Animate Text in Video',
#   'Weaphones™ Gun Sim Free Vol 1',
#   'AP Themes for Kustom/KLWP',
#   'Accounting Quiz (AQ) Malaysia',
#   'Guns of Boom - Online Shooter',
#   'AR Toybox - Augmented Reality Demos',
#   'Kingdoms at War: Hardcore PVP',
#   'Undertale AU Amino',
#   'AU Spark',
#   'AU Students Zone (Result 2016)',
#   'AU Call Blocker - Block Unwanted Calls Texts 2018',
#   'Dance On Mobile',
#   'AX Video Player',
#   'AZ Lottery Players Club',
#   'First Credit Union (AZ) Mobile',
#   'AZ Practice Test & Questions',
#   'Survival Mobile:10,000 BC',
#   'BackCountry Navigator TOPO GPS PRO',
#   'BD Field Force',
#   'Rabbithole',
#   'Block Gun 3D: Ghost Ops',
#   'LEGO ® Batman: Beyond Gotham',
#   'Sisense Mobile BI',
#   'Real Casino:Slot,Keno,BJ,Poker',
#   'HON. B.J. ACS COLLEGE ALE',
#   'BJ Toys',
#   'BL Holo Theme',
#   'BL Mobile Banking',
#   'BL Taxi',
#   'NOOK Audiobooks',
#   'The Legacy (Full)',
#   'Zowi App',
#   'BT Church',
#   'Keyboard Theme Gate Flat BW',
#   'Bixby Button Remapper - bxActions Pro / Coffee',
#   'Lollipop Launcher Plus',
#   'Train driving simulator',
#   'Pixelmania - Color by number & create pixel art',
#   'BZ Reminder',
#   'CA UIM Mobile',
#   'CB Fit',
#   'C B Patel Health Club',
#   'DIY Crafts Cds',
#   'CG Shikshak',
#   'Chrome Canary (Unstable)',
#   'FlashLight HD LED Pro',
#   'Courier Journal',
#   '📏 Smart Ruler ↔️ cm/inch measuring for homework!',
#   'Centimeter Ruler',
#   'CP Installer App',
#   'First Tech Federal CU',
#   'MARVEL Avengers Academy',
#   'Dollar General - Digital Coupons, Ads And More',
#   'Euro Truck Driver (Simulator)',
#   'Free Poker Games : Downtown Casino - Texas Holdem',
#   'WFVS 2018 | WhatApp Full Video Status & Downloader',
#   'do',
#   'Do I Snore or Grind',
#   'Dr. Panda Ice Cream Truck Free',
#   'Night: DU Launcher Theme',
#   'Portes du Soleil',
#   '4K Ultra Camera',
#   'DV Lottery Simulator',
#   '4K VIDEO PLAYER ULTRA HD'],
#  ['Monster Truck Stunt 3D 2019',
#   'Marvel Unlimited',
#   'WhatsApp Messenger',
#   'NoBuffDating - Free Dating App',
#   'Lynda - Online Training Videos',
#   '7 Day Food Journal Challenge',
#   'Metal Soldiers 2',
#   'Muscle Premium - Human Anatomy, Kinesiology, Bones',
#   'tökr',
#   'SnipSnap Coupon App',
#   'Vegetable Fun',
#   'learn c in hindi',
#   'FollowMeter for Instagram',
#   'Zaatar w Zeit',
#   'Anime X Wallpaper',
#   'CPU-Z',
#   'AE Sudoku',
#   'Surah Al-Waqiah',
#   'Weaphones™ Gun Sim Free Vol 1',
#   'Comics Reader',
#   'Chrome Canary (Unstable)'],
#  ['Paper flowers instructions',
#   'HD Mickey Minnie Wallpapers',
#   'Pencil Sketch Drawing',
#   'Art Drawing Ideas',
#   'How to draw Ladybug and Cat Noir',
#   'Install images with music to make video without Net - 2018',
#   'Monster Truck Stunt 3D 2019',
#   'Sweet Selfie Beauty Camera',
#   'English Persian Dictionary',
#   'All Maths Formulas',
#   'Azpen eReader',
#   'Google My Business',
#   'Curriculum vitae App CV Builder Free Resume Maker',
#   'TurboScan: scan documents and receipts in PDF',
#   'Microsoft Remote Desktop',
#   'Verify - Receipts & Expenses',
#   'The Vietnam Story - Fun Stories',
#   'Marvel Unlimited',
#   'imo free video calls and chat',
#   'Hot or Not - Find someone right now',
#   'NoBuffDating - Free Dating App',
#   'USA Singles Meet, Match and Date Free - Date',
#   'BBW Dating & Curvy Singles Chat- LargeFriends',
#   'A hundred',
#   'Live Talk - Free Text and Video Chat',
#   'Kids Mode',
#   'GRE Prep & Practice by Magoosh',
#   'Pluto TV - It’s Free TV',
#   'Google Play Games',
#   'AMC Theatres',
#   'Animal Planet GO',
#   'DramaFever: Stream Asian Drama Shows & Movies',
#   'Investigation Discovery GO',
#   'Crackle - Free TV & Movies',
#   'The CW',
#   'BET NOW - Watch Shows',
#   'Hulu: Stream TV, Movies & more',
#   'Lifetime - Watch Full Episodes & Original Movies',
#   'Comedy Central',
#   'CW Seed',
#   'PayPal',
#   'Bank of Brazil',
#   'Wells Fargo Daily Change',
#   'Simple - Better Banking',
#   'E*TRADE Mobile',
#   'HDFC Bank MobileBanking',
#   'Simple Recipes',
#   'Easy and quick desserts',
#   'Dr. Oetker recipe ideas',
#   'Dairy Queen',
#   'OpenRice',
#   'SarashpazPapion (Cooking with Chef Bowls)',
#   'Wendy’s – Food and Offers',
#   'Healthy Recipes Free',
#   'Cookbook Recipes',
#   'Yummly Recipes & Shopping List',
#   'Cookpad',
#   'Instacart: Grocery Delivery',
#   'Foursquare City Guide',
#   'Eat24 Food Delivery & Takeout',
#   'BeyondMenu Food Delivery',
#   'EatStreet Food Delivery App',
#   'Caviar - Food Delivery',
#   'Uber Eats: Local Food Delivery',
#   'Seamless Food Delivery/Takeout',
#   'Step Counter - Calorie Counter',
#   'Pedometer',
#   'Step Counter - Pedometer Free & Calorie Counter',
#   'Sportractive GPS Running Cycling Distance Tracker',
#   'Fat Burning Workout - Home Weight lose',
#   'Keep Trainer - Workout Trainer & Fitness Coach',
#   'My Diet Diary Calorie Counter',
#   'Living Smart Home',
#   'Trulia Rent Apartments & Homes',
#   'Best New Ringtones 2018 Free 🔥 For Android™',
#   'Chictopia',
#   'Relax Rain ~ Rain Sounds',
#   '7 Day Food Journal Challenge',
#   'Block Puzzle Classic Legend !',
#   'PAC-MAN',
#   'Jungle Marble Blast',
#   'Farm Fruit Pop: Party Time',
#   'Homescapes',
#   'The Room: Old Sins',
#   'Super ABC! Learning games for kids! Preschool apps',
#   'Educational Games 4 Kids',
#   'Candy Smash',
#   'Drawing for Kids Learning Games for Toddlers age 3',
#   'Toddler Kids Puzzles PUZZINGO',
#   'Plants vs. Zombies™ Heroes',
#   'Little Fire Station',
#   'Ice Cream Jump',
#   'Checkers ✔️',
#   'My Little Pony Celebration',
#   'Muscle Premium - Human Anatomy, Kinesiology, Bones',
#   'Blood Pressure Log - MyDiary',
#   'CVS Caremark',
#   'Mayo Clinic',
#   'KBA-EZ Health Guide',
#   'Snapchat',
#   'Golden telegram',
#   'Periscope - Live Video',
#   'MeetMe: Chat & Meet New People',
#   'TwitCasting Live',
#   'OfferUp - Buy. Sell. Offer Up',
#   'Horn, free country requirements',
#   'Home & Shopping - Only in apps. 10% off + 10% off',
#   'Family Dollar',
#   "ROMWE - Women's Fashion",
#   'Checkout 51: Grocery coupons',
#   'SavingStar - Grocery Coupons',
#   'Shopkick: Free Gift Cards, Shop Rewards & Deals',
#   'Urban Outfitters',
#   'HD Camera Ultra',
#   'Photo Effects Pro',
#   'No Crop & Square for Instagram',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'BeSoccer - Soccer Live Score',
#   'Speed Boat Racing',
#   'CBS Sports Fantasy',
#   'JAL (Domestic and international flights)',
#   'SNCF',
#   'Samsung Calculator',
#   'Google Korean Input',
#   'Smart Keyboard Trial',
#   'Hola Launcher- Theme,Wallpaper',
#   'Dolphins Live Wallpaper',
#   'HTC Calendar',
#   'Wunderlist: To-Do List & Tasks',
#   'Planner Pro-Personal Organizer',
#   'Google Slides',
#   'Family Album Mitene: Private Photo & Video Sharing',
#   'VLC for Android',
#   'Dailyhunt (Newshunt) - Latest News, Viral Videos',
#   'Reddit: Social News, Trending Memes & Funny Videos',
#   'Asahi Shimbun Digital',
#   'Bloomberg: Market & Financial News',
#   'ABC News - US & World News',
#   'Yandex.Trains',
#   'B-Messenger Video Chat',
#   'C4droid - C/C++ compiler & IDE',
#   'CL Mobile - Classifieds for Craigslist',
#   'Discord - Chat for Gamers',
#   'What was I in my Past Life',
#   'Magic Tiles - TWICE Edition (K-Pop)',
#   'Dark Infusion Substratum Theme for Android N & O',
#   'Google I/O 2018',
#   'Learn R - Programming Concepts',
#   'Channel U',
#   'Route Z',
#   'AB Click2Shop',
#   '5 Minute Ab Workouts',
#   'Weather & Radar Pro - Ad-Free',
#   'Photo Compress 2.0 - Ad Free',
#   'Brave Browser: Fast AdBlocker',
#   'Adobe Premiere Clip',
#   'AE Sudoku',
#   'AE 3D MOTOR :Racing Games Free',
#   'AE Bulletins',
#   'Bazar.af',
#   'VR AG Racing for Cardboard',
#   'Draw a Stickman: EPIC Free',
#   'Mobile Legends: Bang Bang',
#   'Weaphones™ Gun Sim Free Vol 1',
#   'UniFi',
#   'SAMURAI vs ZOMBIES DEFENSE',
#   'Rivals at War: Firefight',
#   'AU Students Zone (Result 2016)',
#   'Dance On Mobile',
#   'Adventure Xpress',
#   'Quran Khmer Offline AY',
#   'iMediaShare – Photos & Music',
#   'NB|AZ Mobile Banking',
#   'Arizona Trail',
#   'PBA® Bowling Challenge',
#   'Comics Reader',
#   'Be My Princess 2',
#   'BGCN TV',
#   'ALL-IN-ONE PACKAGE TRACKING',
#   'Photo Editor - BPhoto',
#   'BI Mobile',
#   'BK Dinos',
#   'NOOK Audiobooks',
#   'Calendars (En, Bn, Ar)',
#   'BN Pro BlueICS HD Text',
#   'BP World Energy',
#   'Vlogger Go Viral - Tuber Game',
#   'Banco Sabadell App. Your mobile bank',
#   'BT Camera',
#   'BitTorrent®- Torrent Downloads',
#   'BT Mobile',
#   'Casa de Bolsa Bx+ Móvil',
#   'Lollipop Launcher Plus',
#   'Train driving simulator',
#   'Driving Zone',
#   'Glitter Color By Number - Glitter Number Coloring',
#   'Adult Color by Number Book - Paint Mandala Pages',
#   'Best Hairstyles step by step',
#   'ePN Cashback AliExpress',
#   'Elite Commando Shooting War',
#   'CA UIM Mobile',
#   'CB Bank Mobile Banking',
#   'CB Fit',
#   'Football-CB GO Clock Theme',
#   'ARK: Survival Evolved',
#   'CF Calculator',
#   'FlashLight HD LED Pro',
#   'China Town Auto Theft 2',
#   'Teeny Titans - Teen Titans Go!',
#   'CP Ready',
#   'CQ: Lost In Transmission',
#   'Quiz for Clash Royale™',
#   'JavaScript Editor CR',
#   'CS Interview FAQs',
#   'CV Samples 2018',
#   'DB Customer Connect',
#   'DG Mobile',
#   'English for Everyone',
#   'CritDice - Dice Roller',
#   'Free Poker Games : Downtown Casino - Texas Holdem',
#   'Do I Snore or Grind',
#   'Best DP and Status (Daily Updates Photos)',
#   'Dr. Panda Ice Cream Truck Free',
#   'Night: DU Launcher Theme',
#   'Officiel du SCRABBLE LAROUSSE',
#   'DV Lottery Photo Tool',
#   '4K Ultra Camera',
#   'DV Lottery Simulator',
#   'US DV Lottery 2019'],
#  ['Pixel Draw - Number Art Coloring Book',
#   'Paper flowers instructions',
#   'Smoke Effect Photo Maker - Smoke Editor',
#   'Garden Coloring Book',
#   'Photo Designer - Write your name with shapes',
#   '350 Diy Room Decor Ideas',
#   'HD Mickey Minnie Wallpapers',
#   'Art Drawing Ideas',
#   'How to draw Ladybug and Cat Noir',
#   'Ultimate F1 Racing Championship',
#   'CDL Practice Test 2018 Edition',
#   'Super Cars Wallpapers And Backgrounds',
#   'Pick Your Part Garage',
#   'Used car search Goo net whole car Go to net',
#   'CarMax – Cars for Sale: Search Used Car Inventory',
#   'SKencar',
#   'Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'ipsy: Makeup, Beauty, and Tips',
#   'Wattpad 📖 Free Books',
#   'E-Book Read - Read Book for free',
#   'Microsoft Remote Desktop',
#   'AT&T Visual Voicemail',
#   'Free Dating App & Flirt Chat - Match with Singles',
#   'Live Talk - Free Text and Video Chat',
#   'Learn Spanish - Español',
#   'English Grammar Test',
#   'Math Tricks',
#   'Learn English for beginners',
#   'Coursera: Online courses',
#   'Peak – Brain Games & Training',
#   'SAT Vocabulary',
#   'Learn English with Aco',
#   'Homework Planner',
#   'SoloLearn: Learn to Code for Free',
#   'Sago Mini Hat Maker'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Coloring book moana',
#   'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Sketch - Draw & Paint',
#   'Paper flowers instructions',
#   'Smoke Effect Photo Maker - Smoke Editor',
#   'Garden Coloring Book',
#   'Kids Paint Free - Drawing Fun',
#   'Text on Photo - Fonteee',
#   'Mandala Coloring Book',
#   'Learn To Draw Kawaii Characters',
#   'Logo Maker - Small Business',
#   "Boys Photo Editor - Six Pack & Men's Suit",
#   'HD Mickey Minnie Wallpapers',
#   'Pencil Sketch Drawing',
#   'Art Drawing Ideas',
#   'Easy Origami Ideas',
#   'I Creative Idea',
#   'How to draw Ladybug and Cat Noir',
#   'PIP Camera - PIP Collage Maker',
#   'Sad Poetry Photo Frames 2018',
#   'Popsicle Sticks and Similar DIY Craft Ideas',
#   'Install images with music to make video without Net - 2018',
#   'Little Teddy Bear Colouring Book Game',
#   'Monster Truck Stunt 3D 2019',
#   'Ultimate F1 Racing Championship',
#   'Gas Prices (Germany only)',
#   'Extreme Rally Championship',
#   'ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'Used cars for sale - Trovit',
#   'PDD-UA',
#   'AutoScout24 Switzerland – Find your new car',
#   'auto fines',
#   'Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'Inquiry Fines and Debits of Vehicles',
#   'Natural recipes for your beauty',
#   'Hairstyles step by step',
#   'Selfie Camera',
#   'Sweet Selfie Beauty Camera',
#   'Colors of white in Urdu',
#   'Haircut Tutorials/Haircut Videos',
#   'Sticker Camera - Selfie Filters, Beauty Camera',
#   'E-Book Read - Read Book for free',
#   'Cool Reader',
#   'FBReader: Favorite Book Reader',
#   'Google Play Books',
#   'AlReader -any text book reader',
#   'FamilySearch Tree',
#   'Cloud of Books',
#   'ReadEra – free ebook reader',
#   'Ebook Reader',
#   'Pdf Book Download - Read Pdf Book',
#   'Moon+ Reader',
#   'Google My Business',
#   'USPS MOBILE®',
#   'Curriculum vitae App CV Builder Free Resume Maker',
#   'Facebook Pages Manager',
#   'Polaris Office for LG',
#   'Jobs in Alabama - Jobs in Alba',
#   'Easy Installer - Apps On SD',
#   'Quick PDF Scanner + OCR FREE',
#   'SignEasy | Sign and Fill PDF and other Documents',
#   'Genius Scan - PDF Scanner',
#   'TurboScan: scan documents and receipts in PDF',
#   'Xero Accounting Software',
#   'MailChimp - Email, Marketing Automation',
#   'Asana: organize team projects',
#   'Invoice & Time Tracking - Zoho',
#   'Microsoft Remote Desktop',
#   'Start Meeting',
#   'Verify - Receipts & Expenses',
#   'GANMA! - All original stories free of charge for all original comics',
#   'Manga - read Thai translation',
#   'The Vietnam Story - Fun Stories',
#   'Dragon Ball Wallpaper - Ringtones',
#   'DC Comics',
#   'Marvel Unlimited',
#   'Manga AZ - Manga Comic Reader',
#   "pixiv comic - everyone's manga app",
#   'Funny Jokes and Stories 2018',
#   'Best Wallpapers Backgrounds(100,000+ 4K HD)',
#   'think Comics',
#   'Memes Button',
#   'WhatsApp Messenger',
#   'Google Chrome: Fast & Secure',
#   'Messenger Lite: Free Calls & Messages',
#   'My Tele2',
#   'Firefox Browser fast & private',
#   'Yahoo Mail – Stay Organized',
#   'imo free video calls and chat',
#   'Contacts',
#   'Call Free – Free Call',
#   'Browser 4G',
#   'MegaFon Dashboard',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'Chrome Dev',
#   'Who',
#   'Skype Lite - Free Video Call & Chat',
#   'WeChat',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'My magenta',
#   'Telegram',
#   'Puffin Web Browser',
#   'AT&T Visual Voicemail',
#   'GMX Mail',
#   'UC Browser - Fast Download Private & Secure',
#   'My Vodacom SA',
#   'BBM - Free Calls & Messages',
#   'InBrowser - Incognito Browsing',
#   'Puffin Browser Pro',
#   'Contacts+',
#   'Safest Call Blocker',
#   'RocketDial Dialer & Contacts',
#   'CallApp: Caller ID, Blocker & Phone Call Recorder',
#   'Call Control - Call Blocker',
#   'Sync.ME – Caller ID & Block',
#   'Truecaller: Caller ID, SMS spam blocking & Dialer',
#   'Caller ID +',
#   'K-9 Mail',
#   'Email TypeApp - Mail App',
#   'All Email Providers',
#   'SolMail - All-in-One email app',
# ...
#   'Fat Burning Workout - Home Weight lose',
#   'Calorie Counter - MyNetDiary',
#   'Safeway',
#   'justWink Greeting Cards',
#   '7 Day Food Journal Challenge',
#   '8 Ball Pool',
#   'Flow Free',
#   'Bowmasters',
#   'Tomb of the Mask',
#   'Metal Soldiers 2',
#   'Runner 3d like',
#   'Candy Smash',
#   'Blood Pressure Log - MyDiary',
#   'CVS Caremark',
#   'Blue CareOnDemand',
#   'Golden telegram',
#   'SnipSnap Coupon App',
#   'Urban Outfitters',
#   'FreePrints – Free Photos Delivered',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'Hopper - Watch & Book Flights',
#   'SNCF',
#   'CWT To Go',
#   'ASUS SuperNote',
#   'ARY NEWS',
#   'Disney Magic Timer by Oral-B',
#   'B-Messenger Video Chat',
#   'learn c in hindi',
#   'C Programs Handbook',
#   'What was I in my Past Life',
#   'Magic Tiles - TWICE Edition (K-Pop)',
#   'AB Click2Shop',
#   'Photo Compress 2.0 - Ad Free',
#   'Adobe Premiere Clip',
#   'AE Sudoku',
#   'AE Archer',
#   'Surah Al-Waqiah',
#   'Mobile Legends: Bang Bang',
#   'UniFi',
#   'British Columbia Tourist Places (Guide)',
#   'British Columbia License',
#   'Comics Reader',
#   'Audio Murli Glossary For BK',
#   'The Legacy (Full)',
#   'Boom Beach',
#   'ARK: Survival Evolved',
#   'FlashLight HD LED Pro',
#   'Euro Truck Driver (Simulator)',
#   'wikiHow: how to do anything',
#   "Dr. Panda's Swimming Pool",
#   'DV 2018 Winners Guide'],
#  ['Paper flowers instructions',
#   'Garden Coloring Book',
#   'Text on Photo - Fonteee',
#   'Learn To Draw Kawaii Characters',
#   'FlipaClip - Cartoon animation',
#   'ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'Used cars for sale - Trovit',
#   'CarMax – Cars for Sale: Search Used Car Inventory',
#   'RST - Sale of cars on the PCT',
#   'USPS MOBILE®',
#   'Curriculum vitae App CV Builder Free Resume Maker',
#   'Myanmar 2D/3D',
#   'Quick PDF Scanner + OCR FREE',
#   'Tiny Scanner Pro: PDF Doc Scan',
#   'Invoice & Time Tracking - Zoho',
#   'Microsoft Remote Desktop',
#   'Start Meeting',
#   'Verify - Receipts & Expenses',
#   "pixiv comic - everyone's manga app",
#   'Funny Jokes and Stories 2018',
#   'Best Wallpapers Backgrounds(100,000+ 4K HD)',
#   'Google Chrome: Fast & Secure',
#   'Opera Browser: Fast and Secure',
#   'Google Voice',
#   'Who',
#   'WeChat',
#   'All Email Providers',
#   'Herpes Dating: 1,000K+ Singles',
#   'A hundred',
#   'Girls Live Chat - Free Text & Video Chat',
#   'Thai Handwriting',
#   'Learn English for beginners',
#   'GRE Prep & Practice by Magoosh',
#   'SAT Vocabulary',
#   'Viki: Asian TV Dramas & Movies',
#   'LOL Pics (Funny Pictures)',
#   'PTI Flex Maker, Photo Frame Editor & Songs 2018',
#   'Emmabodafestivalen',
#   'Capitec Remote Banking',
#   'Alfa-Bank (Alfa-Bank)',
#   'Even - organize your money, get paid early',
#   'MetaTrader 4',
#   'Stock Trainer: Virtual Trading (Stock Markets)',
#   'Starbucks',
#   'Dairy Queen',
#   'Little Caesars',
#   'Recipes Pastries and homemade pies More than 500 recipes for pastries',
#   'My Recipes Cookbook : RecetteTek',
#   'EatStreet Food Delivery App',
#   'Step Counter - Calorie Counter',
#   'Six Pack in 30 Days - Abs Workout',
#   '30 Day Fitness Challenge - Workout at Home',
#   'Sworkit: Workouts & Fitness Plans',
#   'Daily Yoga - Yoga Fitness Plans',
#   'Free Meditation - Take a Break',
#   'My Chakra Meditation 2',
#   'Relax Melodies P: Sleep Sounds',
#   'Headspace: Meditation & Mindfulness',
#   'My Cycles Period and Ovulation',
#   'Water Drink Reminder',
#   'Technutri - calorie counter, diet and carb tracker',
#   'Calorie Counter - MyNetDiary',
#   'Keller Williams Real Estate',
#   'Relax Rain ~ Rain Sounds',
#   'Hill Climb Racing',
#   'Doodle Jump',
#   'Jewels Legend - Match 3 Puzzle',
#   'Bubble Shooter Genies',
#   'Gems or jewels ?',
#   'Jewels classic Prince',
#   'Fruit Block - Puzzle Legend',
#   'Marble Woka Woka 2018 - Bubble Shooter Match 3',
#   'Racing in Car 2',
#   'Candy Smash',
#   'Dr. Panda Restaurant 3',
#   'School of Dragons',
#   'LEGO® Juniors Create & Cruise',
#   'Thomas & Friends: Go Go Thomas',
#   'Paw Patrol by ShuffleCards',
#   'Ice Cream Jump',
#   'Disney Magic Kingdoms: Build Your Own Magical Park',
#   'Turbo FAST',
#   'Robots Vs Zombies: Transform To Race And Fight',
#   'Nancy Drew Codes and Clues',
#   'Masha and the Bear Child Games',
#   'Checkers ✔️',
#   'Block Puzzle : Night in Egypt',
#   'Pino chess',
#   'TO-FU Oh!SUSHI',
#   "Dr. Panda & Toto's Treehouse",
#   'CCHT PREP',
#   'Acupuncture Assistant',
#   'MyQuest for Patients',
#   'DreamMapper',
#   'Mayo Clinic',
#   'live Point',
#   'Christella VoiceUp',
#   'Free Hypnosis',
#   'e-Anatomy',
#   'Sway Medical',
#   'Cochrane Library',
#   'Tablet Reminder',
#   'KBA-EZ Health Guide',
#   "You're an Anime",
#   'VetCode',
#   'Clinic Doctor EHr',
#   'Amino: Communities and Chats',
#   'Quora',
#   'Kate Mobile for VK',
#   'Tapatalk - 100,000+ Forums',
#   'We Heart It',
#   'uCiC- Videos and Photos on demand',
#   'OfferUp - Buy. Sell. Offer Up',
#   'Horn, free country requirements',
#   'Family Dollar',
#   'Myntra Online Shopping App',
#   'Flipkart Online Shopping App',
#   'Chilindo',
#   'Rossmann PL',
#   'SnipSnap Coupon App',
#   'SavingStar - Grocery Coupons',
#   'RetailMeNot - Coupons, Deals & Discount Shopping',
#   'Groupon - Shop Deals, Discounts & Coupons',
#   'Mercari: The Selling App',
#   'Urban Outfitters',
#   'Receipt Hog - Receipts to Cash',
#   'Savory - Deals,Freebies,Sales',
#   'REI – Shop Outdoor Gear',
#   'Pretty Makeup, Beauty Photo Editor & Snappy Camera',
#   'Wondershare PowerCam',
#   'Mega Photo',
#   'Beauty Makeup Snappy Collage Photo Editor - Lidow',
#   'Lapse It • Time Lapse • Pro',
#   'EyeEm - Camera & Photo Filter',
#   'Pic Stitch - #1 Collage Maker',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'Yahoo Fantasy Sports - #1 Rated Fantasy App',
#   'Eurosport',
#   'ESPN Fantasy Sports',
#   'Mercato foot by Maxifoot',
#   'WatchESPN',
#   'CBS Sports Fantasy',
#   'Live Golf Scores - US & European Golf',
#   'Trip by Skyscanner - City & Travel Guide',
#   'Yatra - Flights, Hotels, Bus, Trains & Cabs',
#   'Find Dining Restaurant Finder',
#   'Flights',
#   'Calculator - free calculator ,multi calculator app',
#   'ZenUI Keyboard – Emoji, Theme',
#   'Files Go by Google: Free up space on your phone',
#   'File Manager -- Take Command of Your Files Easily',
#   'Phone',
#   'Share Music & Transfer Files - Xender',
#   'Alarm Clock',
#   'Brightest LED Flashlight',
#   'Fraction Calculator Plus Free',
#   'Fancy Widgets',
#   'Kairo XP (for HD Widgets)',
#   'ADW Launcher 2',
#   'TouchPal Purple Butterfly Theme',
#   'Google Calendar',
#   'Yandex.Disk',
#   'Loop - Habit Tracker',
#   'Trello',
#   'Google Slides',
#   'Vegetable Fun',
#   "AEMET's time",
#   'OnePlus Gallery',
#   'PowerDirector Video Editor App: 4K, Slow Mo & More',
#   'Tencent Video - Supporting the whole network',
#   'Tencent News',
#   'Dezeen Magazine RSS Reader',
#   'NAVITIME - Map & Transfer Navi',
#   'Karta GPS - Offline Navigation',
#   'Yandex.Trains',
#   "Lep's World 2 🍀🍀",
#   'Wolfify - Be a Werewolf',
#   'Disney Magic Timer by Oral-B',
#   'Next Launcher 3D Theme Hit-B',
#   'C4droid - C/C++ compiler & IDE',
#   'C Programming Zone',
#   'CPlus for Craigslist - Officially Licensed',
#   'C BOOK-C PROGRAMS',
#   'FRONTLINE COMMANDO: D-DAY',
#   'Lookout Security & Antivirus',
#   'MJX H',
#   'Add-On: Alcatel (h)',
#   'Mobile Number Tracker',
#   'M-Files',
#   'G-Pix [Android P] Dark EMUI 8/5 THEME',
#   'Q*bert: Rebooted',
#   'DJMAX TECHNIKA Q - Music Game',
#   'Q Operator',
#   'Elemental Knights R Platinum',
#   'Wonder5 Masters R',
#   "Don't Panic with Andrew J.",
#   'U-Haul',
#   'Vimeo',
#   'VideoShow-Video Editor, Video Maker, Beauty Camera',
#   'Mirk V Launcher Theme',
#   'IRS W-9 form',
#   'Adobe Premiere Clip',
#   'FilmoraGo - Free Video Editor',
#   "What's Up",
#   'Picai - Smart AI Camera',
#   'Age of AI: War Strategy',
#   'Weapon AK-74 Live Wallpaper',
#   'AK Lodi Films',
#   'Hafizi Quran 15 lines per page',
#   'Quran for Android',
#   'Surah Al-Waqiah',
#   'Who am I? (Biblical)'],
#  ['Monster Truck Stunt 3D 2019',
#   'NoBuffDating - Free Dating App',
#   'Live Talk - Free Text and Video Chat',
#   'Thai Handwriting',
#   'Lynda - Online Training Videos',
#   'AMC Theatres',
#   'Animal Planet GO',
#   'DramaFever: Stream Asian Drama Shows & Movies',
#   'Investigation Discovery GO',
#   'Crackle - Free TV & Movies',
#   'The CW',
#   'BET NOW - Watch Shows',
#   'Univision NOW - Live TV and On Demand',
#   'Comedy Central',
#   'Google Pay',
#   'Simple - Better Banking',
#   'OpenRice',
#   'My Recipes Cookbook : RecetteTek',
#   'Instacart: Grocery Delivery',
#   'Pizza Hut',
#   'Seamless Food Delivery/Takeout',
#   'Sportractive GPS Running Cycling Distance Tracker',
#   'Garmin Connect™',
#   'BetterMe: Weight Loss Workouts',
#   'Tee and Mo Bath Time Free',
#   'Journal Club: Medicine',
#   'DreamMapper',
#   "ROMWE - Women's Fashion",
#   'EyeEm - Camera & Photo Filter',
#   'Dolphins Live Wallpaper',
#   'BBC Persian | BBC Farsi News',
#   'Topbuzz: Breaking News, Videos & Funny GIFs',
#   'What was I in my Past Life',
#   'AE Video Poker',
#   'Permit Test AZ Arizona MVD DOT',
#   'BD All Results',
#   'Treadmill Workouts Free (P)',
#   'Propel BI APP',
#   'Zowi App',
#   'Project Fi by Google',
#   'CB Bank Mobile Banking',
#   'FlashLight HD LED Pro',
#   'Teeny Titans - Teen Titans Go!',
#   'Counter Terrorist Gun Strike CS: Special Forces',
#   'Bank Of Cyprus',
#   'Dr. Parker : Real car parking simulation'],
#  ['Art Drawing Ideas',
#   'Monster Truck Stunt 3D 2019',
#   'Quick PDF Scanner + OCR FREE',
#   'Verify - Receipts & Expenses',
#   'Marvel Unlimited',
#   'USA Singles Meet, Match and Date Free - Date',
#   'A hundred',
#   'Live Talk - Free Text and Video Chat',
#   'Lynda - Online Training Videos',
#   'Pluto TV - It’s Free TV',
#   'BET NOW - Watch Shows',
#   'Univision NOW - Live TV and On Demand',
#   'E*TRADE Mobile',
#   'Chick-fil-A',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   'Chef - Recipes & Cooking',
#   'HungerStation',
#   'Delivery yogi.',
#   'SONIC Drive-In',
#   'SUBWAY®',
#   'Dairy Queen',
#   'OpenRice',
#   'SarashpazPapion (Cooking with Chef Bowls)',
#   'Lose Weight in 30 Days',
#   'Sportractive GPS Running Cycling Distance Tracker',
#   'Six Packs for Man–Body Building with No Equipment',
#   'Running Distance Tracker +',
#   'auto Call Recorder 2018',
#   'Jungle Marble Blast',
#   'Coloring & Learn',
#   'Blood Pressure Log - MyDiary',
#   'e-Anatomy',
#   'Hypertension High blood pressure',
#   'Speed Boat Racing',
#   'Live Golf Scores - US & European Golf',
#   'ASUS SuperNote',
#   'National Rail Enquiries',
#   'What was I in my Past Life',
#   'Zapya - File Transfer, Sharing',
#   'AB Click2Shop',
#   'Photo Compress 2.0 - Ad Free',
#   'Digital Clock : Simple, Tiny, Ad-free Desk Clock.',
#   "Five Nights at Freddy's 4 Demo",
#   'Explore British Columbia - BC Travel Guide',
#   'ARK: Survival Evolved',
#   'FlashLight HD LED Pro',
#   'DG Video Editor'],
#  ['Pixel Draw - Number Art Coloring Book',
#   'PIP Camera - PIP Collage Maker',
#   'Verify - Receipts & Expenses',
#   'Google Chrome: Fast & Secure',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'Thai Handwriting',
#   'Harkins Theatres',
#   'FOX NOW - On Demand & Live TV',
#   'hellofood - Food Delivery',
#   'Starbucks',
#   'Recipes Pastries and homemade pies More than 500 recipes for pastries',
#   'Six Pack in 30 Days - Abs Workout',
#   'auto Call Recorder 2018',
#   'Chart - Myanmar Keyboard',
#   'Bowmasters',
#   'Jungle Marble Blast',
#   'Endless Numbers',
#   'Youper - AI Therapy',
#   'Amino: Communities and Chats',
#   'Tapatalk - 100,000+ Forums',
#   'We Heart It',
#   'Urban Outfitters',
#   'learn c in hindi',
#   'FollowMeter for Instagram',
#   'The Maze Runner',
#   'AB Click2Shop',
#   'Fandom: Five Nights at Freddys',
#   'Sic Bo Rave',
#   'Blood Pressure Info',
#   'Bubble',
#   'China Town Auto Theft 2',
#   'Gang Wars of San Andreas',
#   'Calvin Klein – US Store',
#   'DL Hughley',
#   '+Download 4 Instagram Twitter'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Photo Designer - Write your name with shapes',
#   'Animated Photo Editor',
#   'PIP Camera - PIP Collage Maker',
#   'Monster Truck Stunt 3D 2019',
#   'Hairstyles step by step',
#   'Selfie Camera',
#   'AlReader -any text book reader',
#   'Verify - Receipts & Expenses',
#   'Marvel Unlimited',
#   'Cricket Visual Voicemail',
#   'Opera Browser: Fast and Secure',
#   'UC Browser Mini -Tiny Fast Private & Secure',
#   'GMX Mail',
#   'All Email Providers',
#   'Black People Meet Singles Date',
#   'Free Dating & Flirt Chat - Choice of Love',
#   'NoBuffDating - Free Dating App',
#   'Mingle - Online Dating App to Chat & Meet People',
#   'A hundred',
#   'FERZU - Furries Social Network',
#   'WannaMeet – Dating & Chat App',
#   'Live Talk - Free Text and Video Chat',
#   'chat saudi arabia',
#   'Monster Truck Driver & Racing',
#   'Learn English from Persian: Persian to English',
#   'Lynda - Online Training Videos',
#   'Chegg Study - Homework Help',
#   'Regal Cinemas',
#   'Fandango Movies - Times + Tickets',
#   'Harkins Theatres',
#   'AMC Theatres',
#   'Animal Planet GO',
#   'VRV: Anime, game videos & more',
#   'Investigation Discovery GO',
#   'Crackle - Free TV & Movies',
#   'CBS - Full Episodes & Live TV',
#   'Nick',
#   'BET NOW - Watch Shows',
#   'Hulu: Stream TV, Movies & more',
#   'Lifetime - Watch Full Episodes & Original Movies',
#   'LEGO® TV',
#   'SeatGeek – Tickets to Sports, Concerts, Broadway',
#   'PTI Flex Maker, Photo Frame Editor & Songs 2018',
#   'vide-greniers.org',
#   'SUMMER SONIC app',
#   "Picktrainer: India's largest photo contest app",
#   'Google Pay',
#   'Monefy - Money Manager',
#   'Delicious Recipes',
#   'Delivery yogi.',
#   'SONIC Drive-In',
#   'Dairy Queen',
#   'My Recipes Cookbook : RecetteTek',
#   'BigOven Recipes, Meal Planner, Grocery List & More',
#   'Pizza Hut',
#   'Fitbit',
#   'Nike+ Run Club',
#   'Garmin Connect™',
#   'Running Weight Loss Walking Jogging Hiking FITAPP',
#   'My Chakra Meditation',
#   'Period Tracker',
#   'Calorie Counter - MyNetDiary',
#   'Safeway',
#   'Super Slime Simulator - Satisfying Slime App',
#   'Brit + Co',
#   'Zombie Hunter King',
#   'Bowmasters',
#   'Jungle Marble Blast',
#   'Farm Fruit Pop: Party Time',
#   'Color Road',
#   'Crossy Road',
#   'DEAD TARGET: FPS Zombie Apocalypse Survival Games',
#   'Extreme Match',
#   'Zombie Hunter: Post Apocalypse Survival Games',
#   'Agar.io',
#   'Once Upon a Tower',
#   'Super Jabber Jump 3',
#   'Jewels Crush- Match 3 Puzzle',
#   'Candy Smash',
#   'Drawing for Kids Learning Games for Toddlers age 3',
#   'Leo and Tig',
#   'Cutie Cubies',
#   'Extreme Racing 2 - Real driving RC cars game!',
#   'Checkers ✔️',
#   'Blood Pressure Log - MyDiary',
#   'Epocrates Plus',
#   'JH Blood Pressure Monitor',
#   'tökr',
#   'Web Browser & Fast Explorer',
#   'Tapatalk - 100,000+ Forums',
#   'Home & Shopping - Only in apps. 10% off + 10% off',
#   'Blibli.com Online Shopping',
#   "ROMWE - Women's Fashion",
#   'EyeEm - Camera & Photo Filter',
#   'Meitu – Beauty Cam, Easy Photo Editor',
#   'Speed Boat Racing',
#   'AT&T Navigator: Maps, Traffic',
#   'AirAsia',
#   'SNCF',
#   'Where to travel - ticket. hotel. train ticket. car ticket. travel. tickets',
#   'Fancy Widgets',
#   'Tencent News',
#   'NPR News',
#   'Next Launcher 3D Theme Hit-B',
#   'CL Mobile - Classifieds for Craigslist',
#   'learn c in hindi',
#   'codeEazy - C/C++/JAVA',
#   'C Programs Handbook',
#   '101 C Programming Problems',
#   'Discord - Chat for Gamers',
#   'What was I in my Past Life',
#   'FollowMeter for Instagram',
#   'Dino in City-Dinosaur N Police',
#   'Kicker U Lite',
#   'ABS Workout - Belly workout, 30 days AB',
#   'Photo Compress 2.0 - Ad Free',
#   'Adobe Premiere Clip',
#   'AE Sudoku',
#   'AE Order',
#   'Surah Al-Waqiah',
#   'British Columbia License'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Paper flowers instructions',
#   'Smoke Effect Photo Maker - Smoke Editor',
#   'HD Mickey Minnie Wallpapers',
#   'Art Drawing Ideas',
#   'Ultimate F1 Racing Championship',
#   'CDL Practice Test 2018 Edition',
#   'CarMax – Cars for Sale: Search Used Car Inventory',
#   'Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'E-Book Read - Read Book for free',
#   'Live Talk - Free Text and Video Chat',
#   'English Grammar Test',
#   'Learn English for beginners',
#   'Learn English from Persian: Persian to English',
#   'Elevate - Brain Training Games',
#   'SAT Vocabulary',
#   'Banorte Movil',
#   'Fertility Friend Ovulation App']]

# %% [markdown]
# - #### Implement the apriori algorithm for our apps

# %%
association_rules = apriori(record, min_support=0.2, min_confidence=0.2, min_lift=2, min_length=2)
association_results = list(association_rules)

# %%
print(f"There are {len(association_results)} Relation derived.")
# Out:
# There are 35 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'5 Minute Ab Workouts', 'Adobe Premiere Clip'})
# frozenset({'Install images with music to make video without Net - 2018', 'A hundred'})
# frozenset({'Adobe Premiere Clip', 'ARK: Survival Evolved'})
# frozenset({'Golden telegram', 'ARK: Survival Evolved'})
# frozenset({'Adobe Premiere Clip', 'Golden telegram'})
# frozenset({'Adobe Premiere Clip', 'Meitu – Beauty Cam, Easy Photo Editor'})
# frozenset({'All Email Providers', 'Hitwe - meet people and chat'})
# frozenset({'My Vodacom SA', 'All Email Providers'})
# frozenset({'Hitwe - meet people and chat', 'BBW Dating & Curvy Singles Chat- LargeFriends'})
# frozenset({'Chick-fil-A', 'Dairy Queen'})
# frozenset({'Chick-fil-A', 'Fat Burning Workout - Home Weight lose'})
# frozenset({'Chick-fil-A', 'Running Distance Tracker +'})
# frozenset({'Chick-fil-A', 'Starbucks'})
# frozenset({'Starbucks', 'Dairy Queen'})
# frozenset({'Starbucks', 'Fat Burning Workout - Home Weight lose'})
# frozenset({'Mingle - Online Dating App to Chat & Meet People', 'Hitwe - meet people and chat'})
# frozenset({'My Vodacom SA', 'Hitwe - meet people and chat'})
# frozenset({'Install images with music to make video without Net - 2018', 'Verify - Receipts & Expenses'})
# frozenset({'Starbucks', 'Running Distance Tracker +'})
# frozenset({'A hundred', 'All Email Providers', 'Verify - Receipts & Expenses'})
# frozenset({'Cricket Visual Voicemail', 'A hundred', 'Verify - Receipts & Expenses'})
# frozenset({'Install images with music to make video without Net - 2018', 'A hundred', 'Verify - Receipts & Expenses'})
# frozenset({'A hundred', 'Marvel Unlimited', 'Verify - Receipts & Expenses'})
# frozenset({'A hundred', 'Verify - Receipts & Expenses', 'Monster Truck Stunt 3D 2019'})
# frozenset({'NoBuffDating - Free Dating App', 'A hundred', 'Verify - Receipts & Expenses'})
# frozenset({'Selfie Camera', 'A hundred', 'Verify - Receipts & Expenses'})
# frozenset({'Adobe Premiere Clip', 'Golden telegram', 'ARK: Survival Evolved'})
# frozenset({'Adobe Premiere Clip', 'Meitu – Beauty Cam, Easy Photo Editor', 'Verify - Receipts & Expenses'})
# frozenset({'Cricket Visual Voicemail', 'Chick-fil-A', 'Microsoft Remote Desktop'})
# frozenset({'Microsoft Remote Desktop', 'Chick-fil-A', 'Dairy Queen'})
# frozenset({'Chick-fil-A', 'Fat Burning Workout - Home Weight lose', 'Microsoft Remote Desktop'})
# frozenset({'Chick-fil-A', 'Golden telegram', 'Microsoft Remote Desktop'})
# frozenset({'Chick-fil-A', 'Starbucks', 'Microsoft Remote Desktop'})
# frozenset({'Cricket Visual Voicemail', 'Fat Burning Workout - Home Weight lose', 'Microsoft Remote Desktop'})
# frozenset({'Cricket Visual Voicemail', 'Selfie Camera', 'NoBuffDating - Free Dating App'})

# %% [markdown]
# - ## Display the Results :

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print(f"Rule: {items[0]} -> {items[1]}")

    # second index of the inner list
    print(f"Support: {item[1]}")

    # third index of the list located at 0th
    # of the third index of the inner list

    print(f"Confidence: {item[2][0][2]}")
    print(f"Lift: {item[2][0][3]}")
    print("=====================================")
# Out:
# Rule: 5 Minute Ab Workouts -> Adobe Premiere Clip
# Support: 0.22
# Confidence: 0.9166666666666667
# Lift: 2.7777777777777777
# =====================================
# Rule: Install images with music to make video without Net - 2018 -> A hundred
# Support: 0.21
# Confidence: 0.5675675675675675
# Lift: 2.364864864864865
# =====================================
# Rule: Adobe Premiere Clip -> ARK: Survival Evolved
# Support: 0.27
# Confidence: 0.9000000000000001
# Lift: 2.7272727272727275
# =====================================
# Rule: Golden telegram -> ARK: Survival Evolved
# Support: 0.21
# Confidence: 0.7
# Lift: 2.0
# =====================================
# Rule: Adobe Premiere Clip -> Golden telegram
# Support: 0.24
# Confidence: 0.7272727272727272
# Lift: 2.0779220779220777
# =====================================
# Rule: Adobe Premiere Clip -> Meitu – Beauty Cam, Easy Photo Editor
# Support: 0.23
# Confidence: 0.696969696969697
# Lift: 2.3232323232323235
# =====================================
# Rule: All Email Providers -> Hitwe - meet people and chat
# Support: 0.23
# Confidence: 0.7419354838709677
# Lift: 2.318548387096774
# =====================================
# Rule: My Vodacom SA -> All Email Providers
# Support: 0.21
# Confidence: 0.6774193548387096
# Lift: 2.7096774193548385
# =====================================
# Rule: Hitwe - meet people and chat -> BBW Dating & Curvy Singles Chat- LargeFriends
# Support: 0.21
# Confidence: 0.7
# Lift: 2.1875
# =====================================
# Rule: Chick-fil-A -> Dairy Queen
# Support: 0.23
# Confidence: 0.696969696969697
# Lift: 2.248289345063539
# =====================================
# Rule: Chick-fil-A -> Fat Burning Workout - Home Weight lose
# Support: 0.22
# Confidence: 0.6666666666666666
# Lift: 2.083333333333333
# =====================================
# Rule: Chick-fil-A -> Running Distance Tracker +
# Support: 0.2
# Confidence: 0.6060606060606061
# Lift: 2.635046113306983
# =====================================
# Rule: Chick-fil-A -> Starbucks
# Support: 0.24
# Confidence: 0.7272727272727272
# Lift: 2.3460410557184748
# =====================================
# Rule: Starbucks -> Dairy Queen
# Support: 0.2
# Confidence: 0.6451612903225807
# Lift: 2.081165452653486
# =====================================
# Rule: Starbucks -> Fat Burning Workout - Home Weight lose
# Support: 0.2
# Confidence: 0.625
# Lift: 2.0161290322580645
# =====================================
# Rule: Mingle - Online Dating App to Chat & Meet People -> Hitwe - meet people and chat
# Support: 0.21
# Confidence: 0.65625
# Lift: 2.1875
# =====================================
# Rule: My Vodacom SA -> Hitwe - meet people and chat
# Support: 0.2
# Confidence: 0.625
# Lift: 2.5
# =====================================
# Rule: Install images with music to make video without Net - 2018 -> Verify - Receipts & Expenses
# Support: 0.23
# Confidence: 0.9583333333333334
# Lift: 2.0833333333333335
# =====================================
# Rule: Starbucks -> Running Distance Tracker +
# Support: 0.22
# Confidence: 0.9565217391304347
# Lift: 3.0855539971949506
# =====================================
# Rule: A hundred -> All Email Providers
# Support: 0.2
# Confidence: 0.5405405405405406
# Lift: 2.2522522522522523
# =====================================
# Rule: Cricket Visual Voicemail -> A hundred
# Support: 0.23
# Confidence: 0.5
# Lift: 2.0833333333333335
# =====================================
# Rule: Install images with music to make video without Net - 2018 -> A hundred
# Support: 0.2
# Confidence: 0.5405405405405406
# Lift: 2.3501762632197414
# =====================================
# Rule: A hundred -> Marvel Unlimited
# Support: 0.22
# Confidence: 0.5945945945945946
# Lift: 2.050326188257223
# =====================================
# Rule: A hundred -> Verify - Receipts & Expenses
# Support: 0.22
# Confidence: 0.5945945945945946
# Lift: 2.3783783783783785
# =====================================
# Rule: NoBuffDating - Free Dating App -> A hundred
# Support: 0.21
# Confidence: 0.5675675675675675
# Lift: 2.0270270270270268
# =====================================
# Rule: Selfie Camera -> A hundred
# Support: 0.22
# Confidence: 0.5945945945945946
# Lift: 2.1235521235521233
# =====================================
# Rule: Adobe Premiere Clip -> Golden telegram
# Support: 0.2
# Confidence: 0.6666666666666667
# Lift: 2.777777777777778
# =====================================
# Rule: Adobe Premiere Clip -> Meitu – Beauty Cam, Easy Photo Editor
# Support: 0.2
# Confidence: 0.6060606060606061
# Lift: 2.635046113306983
# =====================================
# Rule: Cricket Visual Voicemail -> Chick-fil-A
# Support: 0.24
# Confidence: 0.7272727272727272
# Lift: 2.693602693602693
# =====================================
# Rule: Microsoft Remote Desktop -> Chick-fil-A
# Support: 0.2
# Confidence: 0.6060606060606061
# Lift: 2.635046113306983
# =====================================
# Rule: Chick-fil-A -> Fat Burning Workout - Home Weight lose
# Support: 0.22
# Confidence: 0.6666666666666666
# Lift: 2.564102564102564
# =====================================
# Rule: Chick-fil-A -> Golden telegram
# Support: 0.2
# Confidence: 0.6060606060606061
# Lift: 2.4242424242424243
# =====================================
# Rule: Chick-fil-A -> Starbucks
# Support: 0.21
# Confidence: 0.6363636363636364
# Lift: 2.6515151515151514
# =====================================
# Rule: Cricket Visual Voicemail -> Fat Burning Workout - Home Weight lose
# Support: 0.2
# Confidence: 0.625
# Lift: 2.314814814814815
# =====================================
# Rule: Cricket Visual Voicemail -> Selfie Camera
# Support: 0.2
# Confidence: 0.5405405405405406
# Lift: 2.002002002002002
# =====================================
